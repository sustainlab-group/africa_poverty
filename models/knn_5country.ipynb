# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports-and-Constants" data-toc-modified-id="Imports-and-Constants-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports and Constants</a></span></li><li><span><a href="#Helper-Functions" data-toc-modified-id="Helper-Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Helper Functions</a></span></li><li><span><a href="#Load-DHS-Data" data-toc-modified-id="Load-DHS-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Load DHS Data</a></span></li><li><span><a href="#Load-LSMS-Data" data-toc-modified-id="Load-LSMS-Data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load LSMS Data</a></span><ul class="toc-item"><li><span><a href="#Neal-OOC-setup" data-toc-modified-id="Neal-OOC-setup-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Neal OOC setup</a></span></li></ul></li><li><span><a href="#Neal-NL-and-Labels-vs.-new-NL-and-Labels" data-toc-modified-id="Neal-NL-and-Labels-vs.-new-NL-and-Labels-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Neal NL and Labels vs. new NL and Labels</a></span></li><li><span><a href="#KNN" data-toc-modified-id="KNN-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>KNN</a></span><ul class="toc-item"><li><span><a href="#Neal-OOC-setup" data-toc-modified-id="Neal-OOC-setup-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Neal OOC setup</a></span></li><li><span><a href="#Label-vs.-NL" data-toc-modified-id="Label-vs.-NL-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Label vs. NL</a></span></li><li><span><a href="#Neal-Label-vs.-Neal-NL" data-toc-modified-id="Neal-Label-vs.-Neal-NL-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Neal Label vs. Neal NL</a></span></li><li><span><a href="#Neal-Label-vs.-NL" data-toc-modified-id="Neal-Label-vs.-NL-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Neal Label vs. NL</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Imports and Constants

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from collections import defaultdict
import os
import pickle
import sys

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.neighbors

from batchers import batcher, dataset_constants
from models.histograms import (
    get_per_image_histograms,
    plot_band_hists,
    plot_label_hist,
    split_nl_hist)
from models.linear_model import ridge_cv
from utils.analysis import calc_score, evaluate
from utils.general import load_npz
from utils.plot import scatter_preds

# %%
FOLDS = ['A', 'B', 'C', 'D']
SPLITS = ['train', 'val', 'test']

MEANS = dataset_constants.MEANS_DICT['2009-17']
STD_DEVS = dataset_constants.STD_DEVS_DICT['2009-17']

# %% [markdown]
# # Helper Functions

# %%
def background_gradient(df, cmap, m=None, M=None):
    '''
    Args
    - df: pd.DataFrame
    - cmap: str, name of matplotlib colormap
    - m: float, value corresponding to lowest color in cmap
    - M: float, value corresponding to highest color in cmap

    Returns
    - styles_df: pd.DataFrame
    '''
    if m is None:
        m = np.nanmin(df.values)
    if M is None:
        M = np.nanmax(df.values)
    normed = np.clip((df.values - m) / (M - m), 0, 1)
    normed[np.isnan(normed)] = 0
    cmap = plt.cm.get_cmap(cmap)
    styles = []
    for rgba in cmap(normed.ravel()):
        c = matplotlib.colors.rgb2hex(rgba)
        if np.mean(rgba) < 0.75:
            styles.append(f'background-color: {c}; color: white;')
        else:
            styles.append(f'background-color: {c};')
    styles = np.asarray(styles).reshape(df.shape)
    styles_df = pd.DataFrame(styles, index=df.index, columns=df.columns)
    styles_df[df.isna()] = f'background-color: white'
    return styles_df

# %%
def neal_ooc(df, country_order):
    '''
    Args
    - df: pd.DataFrame
    - countries: list of countries
    '''
    knn = sklearn.neighbors.KNeighborsRegressor(100)
    neal_ooc_df = pd.DataFrame(columns=['train_on', 'eval_on', 'r2'], dtype=np.float32)
    neal_ooc_df.set_index(['train_on', 'eval_on'], inplace=True)
    for train_c in country_order:
        for test_c in country_order:
            if test_c == train_c: continue

            train_mask = (df['country'] == train_c)
            test_mask = (df['country'] == test_c)
            knn.fit(X=df.loc[train_mask, ['neal_nl']].values, y=df.loc[train_mask, 'neal_label'].values)
            preds = knn.predict(X=df.loc[test_mask, ['neal_nl']].values)
            neal_ooc_df.loc[(train_c, test_c), :] = calc_score(
                df.loc[test_mask, 'neal_label'].values, preds, metric='r2')

    rows = country_order
    cols = rows[::-1]

    return neal_ooc_df.stack().reset_index(level=2, drop=True).unstack('train_on').loc[rows, cols]

# %% [markdown]
# # Load DHS Data

# %%
NEAL_DIR = '/atlas/u/nj/dhs/'

# %%
surveys = [
    'malawi_dhs_2010',
    'nigeria_dhs_2013',
    'rwanda_dhs_2010',
    'tanzania_dhs_2010',
    'uganda_dhs_2011',
]

COUNTRIES = ['malawi', 'nigeria', 'rwanda', 'tanzania', 'uganda']
DMSP_COUNTRIES = ['malawi', 'rwanda', 'tanzania', 'uganda']

# %%
df = pd.DataFrame(columns=['lat', 'lon', 'country', 'year', 'neal_nl', 'neal_label', 'nl', 'label'])

# %%
file_path = 'data/dhs_image_hists.npz'
result = load_npz(file_path)
image_hists = result['image_hists']
labels = result['labels']
locs = result['locs']
years = result['years']
nls_center = result['nls_center']
nls_mean = result['nls_mean']

dmsp_mask = years < 2012
viirs_mask = ~dmsp_mask
# Out:
# image_hists: dtype=int64, shape=(19669, 8, 102)
# labels: dtype=float32, shape=(19669,)
# locs: dtype=float32, shape=(19669, 2)
# years: dtype=int32, shape=(19669,)
# nls_center: dtype=float32, shape=(19669,)
# nls_mean: dtype=float32, shape=(19669,)

# %%
loc_to_index = {
    (lat, lon): i
    for i, (lat, lon) in enumerate(locs)
}
assert len(loc_to_index) == len(locs)

# %%
for survey in surveys:
    country, year = survey.split('_dhs_')
    year = int(year)

    folder = os.path.join(NEAL_DIR, survey, 'data')
    image_counts = np.load(os.path.join(folder, 'cluster_image_counts.npy'))
    mask = (image_counts >= 10)

    clocs = np.load(os.path.join(folder, 'cluster_locs.npy'))
    clocs = clocs[mask]

    neal_nls = np.load(os.path.join(folder, 'cluster_nightlights.npy'))
    neal_nls = neal_nls[mask]

    neal_labels = np.load(os.path.join(folder, 'cluster_assets.npy'))
    neal_labels = neal_labels[mask]

    indices = [
        loc_to_index[(lat, lon)]
        for lat, lon in clocs.astype(np.float32)
    ]
    
    cdf = pd.DataFrame(data={
        'lat': clocs[:, 0],
        'lon': clocs[:, 1],
        'country': country,
        'year': year,
        'neal_nl': neal_nls,
        'neal_label': neal_labels,
        'nl': nls_mean[indices],
        'label': labels[indices]
    })
    df = pd.concat([df, cdf])
df.reset_index(inplace=True, drop=True)

# %%
with pd.option_context('display.max_rows', 6):
    display(df)
# Out:
#             lat        lon country  year  neal_nl  neal_label        nl  \
# 0    -14.293995  34.468751  malawi  2010      0.0    0.170203 -0.173862
# 1    -14.791538  35.033085  malawi  2010      0.0   -0.137892 -0.173862
# 2    -13.435848  32.945216  malawi  2010      0.0   -0.265330 -0.173862
# ...         ...        ...     ...   ...      ...         ...       ...
# 3031  -0.796772  29.931162  uganda  2011      5.2    1.256519 -0.103255
# 3032  -0.967814  29.988417  uganda  2011      0.0   -0.419588 -0.173862
# 3033  -0.688925  29.938125  uganda  2011      0.0   -0.209665 -0.173862
#
#          label
# 0    -0.476676
# 1    -0.556283
# 2    -0.559472
# ...        ...
# 3031  0.685674
# 3032 -0.651027
# 3033 -0.565248
#
# [3034 rows x 8 columns]

# %% [markdown]
# # Load LSMS Data

# %%
NEAL_LSMS_DIR = '/atlas/u/nj/lsms'

# %%
lsms_surveys = [
    'malawi_lsms_2013',
    'nigeria_lsms_2012_2013',
    'tanzania_lsms_2012_2013',
    'uganda_lsms_2011_2012',
]

# %%
def load_neal_lsms_data(lsms_surveys):
    df = pd.DataFrame(columns=['lat', 'lon', 'country', 'year', 'neal_nl', 'neal_label'])
    for survey in lsms_surveys:
        country, years = survey.split('_lsms_')
        year = int(years.split('_')[0])

        folder = os.path.join(NEAL_LSMS_DIR, survey, 'data')
        image_counts = np.load(os.path.join(folder, 'cluster_image_counts.npy'))
        mask = (image_counts >= 10)

        households = np.load(os.path.join(folder, 'cluster_households.npy'))
        mask &= (households >= 2)

        clocs = np.load(os.path.join(folder, 'cluster_locs.npy'))
        clocs = clocs[mask]

        neal_nls = np.load(os.path.join(folder, 'cluster_nightlights.npy'))
        neal_nls = neal_nls[mask]

        neal_labels = np.load(os.path.join(folder, 'cluster_consumptions.npy'))
        neal_labels = neal_labels[mask]

        cdf = pd.DataFrame(data={
            'lat': clocs[:, 0],
            'lon': clocs[:, 1],
            'country': country,
            'year': year,
            'neal_nl': neal_nls,
            'neal_label': neal_labels,
        })
        df = pd.concat([df, cdf])
    df.reset_index(inplace=True, drop=True)
    return df

lsms_df = load_neal_lsms_data(lsms_surveys)
with pd.option_context('display.max_rows', 6):
    display(lsms_df)
# Out:
#            lat        lon country  year  neal_nl  neal_label
# 0    -9.504460  33.230200  malawi  2013      0.0    1.460405
# 1    -9.667920  33.393700  malawi  2013      0.0    1.946366
# 2    -9.809980  33.387300  malawi  2013      0.0    1.517353
# ...        ...        ...     ...   ...      ...         ...
# 1408 -0.925602  30.794159  uganda  2011      0.0    2.502750
# 1409 -0.757246  30.807199  uganda  2011      0.0    5.869549
# 1410 -0.151138  30.948854  uganda  2011      0.0    2.363786
#
# [1411 rows x 6 columns]

# %% [markdown]
# ## Neal OOC setup

# %%
lsms_country_row_order = ['malawi', 'uganda', 'tanzania', 'nigeria']
neal_ooc_lsms_df = neal_ooc(df=lsms_df, country_order=lsms_country_row_order)
display(neal_ooc_lsms_df.style.apply(
    background_gradient, cmap='coolwarm',
    m=0.18, M=0.57,
    axis=None).format('{:.2f}'))
# Out:
# <style  type="text/css" >
#     #T_622c9060_9861_11e9_83d4_39d9ea9de529row0_col0 {
#             background-color:  #92b4fe;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row0_col1 {
#             background-color:  #a5c3fe;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row0_col2 {
#             background-color:  #9bbcff;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row0_col3 {
#             background-color:  white;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row1_col0 {
#             background-color:  #f3c7b1;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row1_col1 {
#             background-color:  #ead5c9;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row1_col2 {
#             background-color:  white;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row1_col3 {
#             background-color:  #dedcdb;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row2_col0 {
#             background-color:  #c0282f;
#              color:  white;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row2_col1 {
#             background-color:  white;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row2_col2 {
#             background-color:  #cb3e38;
#              color:  white;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row2_col3 {
#             background-color:  #cf453c;
#              color:  white;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row3_col0 {
#             background-color:  white;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row3_col1 {
#             background-color:  #a5c3fe;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row3_col2 {
#             background-color:  #a6c4fe;
#         }    #T_622c9060_9861_11e9_83d4_39d9ea9de529row3_col3 {
#             background-color:  #8fb1fe;
#         }</style><table id="T_622c9060_9861_11e9_83d4_39d9ea9de529" ><thead>    <tr>        <th class="index_name level0" >train_on</th>        <th class="col_heading level0 col0" >nigeria</th>        <th class="col_heading level0 col1" >tanzania</th>        <th class="col_heading level0 col2" >uganda</th>        <th class="col_heading level0 col3" >malawi</th>    </tr>    <tr>        <th class="index_name level0" >eval_on</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_622c9060_9861_11e9_83d4_39d9ea9de529level0_row0" class="row_heading level0 row0" >malawi</th>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row0_col0" class="data row0 col0" >0.28</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row0_col1" class="data row0 col1" >0.30</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row0_col2" class="data row0 col2" >0.29</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row0_col3" class="data row0 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_622c9060_9861_11e9_83d4_39d9ea9de529level0_row1" class="row_heading level0 row1" >uganda</th>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row1_col0" class="data row1 col0" >0.42</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row1_col1" class="data row1 col1" >0.40</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row1_col3" class="data row1 col3" >0.38</td>
#             </tr>
#             <tr>
#                         <th id="T_622c9060_9861_11e9_83d4_39d9ea9de529level0_row2" class="row_heading level0 row2" >tanzania</th>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row2_col0" class="data row2 col0" >0.56</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row2_col2" class="data row2 col2" >0.55</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row2_col3" class="data row2 col3" >0.54</td>
#             </tr>
#             <tr>
#                         <th id="T_622c9060_9861_11e9_83d4_39d9ea9de529level0_row3" class="row_heading level0 row3" >nigeria</th>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row3_col0" class="data row3 col0" >nan</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row3_col1" class="data row3 col1" >0.30</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row3_col2" class="data row3 col2" >0.31</td>
#                         <td id="T_622c9060_9861_11e9_83d4_39d9ea9de529row3_col3" class="data row3 col3" >0.28</td>
#             </tr>
#     </tbody></table>

# %%
neal_original_lsms_df = pd.DataFrame(data=[
    [.25, .34, .37, .42],
    [.34, .38, .46, .37],
    [.44, .56, .47, .48],
    [.41, .30, .26, .19]
], index=lsms_country_row_order, columns=lsms_country_row_order[::-1])
neal_original_lsms_df.index.name = 'eval_on'
neal_original_lsms_df.columns.name = 'train_on'
display(neal_original_lsms_df.style.apply(
    background_gradient,
    m=0.18, M=0.57,
    cmap='coolwarm', axis=None))
# Out:
# <style  type="text/css" >
#     #T_631f65ba_9861_11e9_83d4_39d9ea9de529row0_col0 {
#             background-color:  #7396f5;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row0_col1 {
#             background-color:  #c4d5f3;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row0_col2 {
#             background-color:  #d9dce1;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row0_col3 {
#             background-color:  #f3c7b1;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row1_col0 {
#             background-color:  #c4d5f3;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row1_col1 {
#             background-color:  #e0dbd8;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row1_col2 {
#             background-color:  #f7a688;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row1_col3 {
#             background-color:  #d9dce1;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row2_col0 {
#             background-color:  #f7b89c;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row2_col1 {
#             background-color:  #bd1f2d;
#              color:  white;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row2_col2 {
#             background-color:  #f59c7d;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row2_col3 {
#             background-color:  #f29274;
#              color:  white;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row3_col0 {
#             background-color:  #f0cdbb;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row3_col1 {
#             background-color:  #a1c0ff;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row3_col2 {
#             background-color:  #7da0f9;
#         }    #T_631f65ba_9861_11e9_83d4_39d9ea9de529row3_col3 {
#             background-color:  #4257c9;
#              color:  white;
#         }</style><table id="T_631f65ba_9861_11e9_83d4_39d9ea9de529" ><thead>    <tr>        <th class="index_name level0" >train_on</th>        <th class="col_heading level0 col0" >nigeria</th>        <th class="col_heading level0 col1" >tanzania</th>        <th class="col_heading level0 col2" >uganda</th>        <th class="col_heading level0 col3" >malawi</th>    </tr>    <tr>        <th class="index_name level0" >eval_on</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_631f65ba_9861_11e9_83d4_39d9ea9de529level0_row0" class="row_heading level0 row0" >malawi</th>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row0_col0" class="data row0 col0" >0.25</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row0_col1" class="data row0 col1" >0.34</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row0_col2" class="data row0 col2" >0.37</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row0_col3" class="data row0 col3" >0.42</td>
#             </tr>
#             <tr>
#                         <th id="T_631f65ba_9861_11e9_83d4_39d9ea9de529level0_row1" class="row_heading level0 row1" >uganda</th>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row1_col0" class="data row1 col0" >0.34</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row1_col1" class="data row1 col1" >0.38</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row1_col2" class="data row1 col2" >0.46</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row1_col3" class="data row1 col3" >0.37</td>
#             </tr>
#             <tr>
#                         <th id="T_631f65ba_9861_11e9_83d4_39d9ea9de529level0_row2" class="row_heading level0 row2" >tanzania</th>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row2_col0" class="data row2 col0" >0.44</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row2_col1" class="data row2 col1" >0.56</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row2_col2" class="data row2 col2" >0.47</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row2_col3" class="data row2 col3" >0.48</td>
#             </tr>
#             <tr>
#                         <th id="T_631f65ba_9861_11e9_83d4_39d9ea9de529level0_row3" class="row_heading level0 row3" >nigeria</th>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row3_col0" class="data row3 col0" >0.41</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row3_col1" class="data row3 col1" >0.3</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row3_col2" class="data row3 col2" >0.26</td>
#                         <td id="T_631f65ba_9861_11e9_83d4_39d9ea9de529row3_col3" class="data row3 col3" >0.19</td>
#             </tr>
#     </tbody></table>

# %%
concat_df = pd.concat(
    [neal_ooc_lsms_df, neal_original_lsms_df],
    keys=['KNN on scalar NL', 'Science paper'])
display(concat_df.style.apply(
    background_gradient, cmap='coolwarm',
    m=0.18, M=0.57,
    axis=None).format('{:.2f}'))
# Out:
# <style  type="text/css" >
#     #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row0_col0 {
#             background-color:  #92b4fe;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row0_col1 {
#             background-color:  #a5c3fe;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row0_col2 {
#             background-color:  #9bbcff;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row0_col3 {
#             background-color:  white;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row1_col0 {
#             background-color:  #f3c7b1;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row1_col1 {
#             background-color:  #ead5c9;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row1_col2 {
#             background-color:  white;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row1_col3 {
#             background-color:  #dedcdb;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row2_col0 {
#             background-color:  #c0282f;
#              color:  white;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row2_col1 {
#             background-color:  white;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row2_col2 {
#             background-color:  #cb3e38;
#              color:  white;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row2_col3 {
#             background-color:  #cf453c;
#              color:  white;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row3_col0 {
#             background-color:  white;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row3_col1 {
#             background-color:  #a5c3fe;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row3_col2 {
#             background-color:  #a6c4fe;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row3_col3 {
#             background-color:  #8fb1fe;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row4_col0 {
#             background-color:  #7396f5;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row4_col1 {
#             background-color:  #c4d5f3;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row4_col2 {
#             background-color:  #d9dce1;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row4_col3 {
#             background-color:  #f3c7b1;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row5_col0 {
#             background-color:  #c4d5f3;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row5_col1 {
#             background-color:  #e0dbd8;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row5_col2 {
#             background-color:  #f7a688;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row5_col3 {
#             background-color:  #d9dce1;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row6_col0 {
#             background-color:  #f7b89c;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row6_col1 {
#             background-color:  #bd1f2d;
#              color:  white;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row6_col2 {
#             background-color:  #f59c7d;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row6_col3 {
#             background-color:  #f29274;
#              color:  white;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row7_col0 {
#             background-color:  #f0cdbb;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row7_col1 {
#             background-color:  #a1c0ff;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row7_col2 {
#             background-color:  #7da0f9;
#         }    #T_6387e1d0_9861_11e9_83d4_39d9ea9de529row7_col3 {
#             background-color:  #4257c9;
#              color:  white;
#         }</style><table id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >train_on</th>        <th class="col_heading level0 col0" >nigeria</th>        <th class="col_heading level0 col1" >tanzania</th>        <th class="col_heading level0 col2" >uganda</th>        <th class="col_heading level0 col3" >malawi</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >eval_on</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529level0_row0" class="row_heading level0 row0" rowspan=4>KNN on scalar NL</th>
#                         <th id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529level1_row0" class="row_heading level1 row0" >malawi</th>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row0_col0" class="data row0 col0" >0.28</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row0_col1" class="data row0 col1" >0.30</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row0_col2" class="data row0 col2" >0.29</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row0_col3" class="data row0 col3" >nan</td>
#             </tr>
#             <tr>
#                                 <th id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529level1_row1" class="row_heading level1 row1" >uganda</th>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row1_col0" class="data row1 col0" >0.42</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row1_col1" class="data row1 col1" >0.40</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row1_col3" class="data row1 col3" >0.38</td>
#             </tr>
#             <tr>
#                                 <th id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529level1_row2" class="row_heading level1 row2" >tanzania</th>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row2_col0" class="data row2 col0" >0.56</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row2_col2" class="data row2 col2" >0.55</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row2_col3" class="data row2 col3" >0.54</td>
#             </tr>
#             <tr>
#                                 <th id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529level1_row3" class="row_heading level1 row3" >nigeria</th>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row3_col0" class="data row3 col0" >nan</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row3_col1" class="data row3 col1" >0.30</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row3_col2" class="data row3 col2" >0.31</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row3_col3" class="data row3 col3" >0.28</td>
#             </tr>
#             <tr>
#                         <th id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529level0_row4" class="row_heading level0 row4" rowspan=4>Science paper</th>
#                         <th id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529level1_row4" class="row_heading level1 row4" >malawi</th>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row4_col0" class="data row4 col0" >0.25</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row4_col1" class="data row4 col1" >0.34</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row4_col2" class="data row4 col2" >0.37</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row4_col3" class="data row4 col3" >0.42</td>
#             </tr>
#             <tr>
#                                 <th id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529level1_row5" class="row_heading level1 row5" >uganda</th>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row5_col0" class="data row5 col0" >0.34</td>
#                         <td id="T_6387e1d0_9861_11e9_83d4_39d9ea9de529row5_col1" class="data row5 col1" >0.38</td>

# %% [markdown]
# # Neal NL and Labels vs. new NL and Labels

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x='neal_label', y='label', hue='country')
r2 = calc_score(df['neal_label'], df['label'], metric='r2')
print('Neal Label vs. Label: r^2 =', r2)
# Out:
# Neal Label vs. Label: r^2 = 0.5900936204254654

# %%
sns.scatterplot(data=df, x='neal_nl', y='nl', hue='country')
r2 = calc_score(df['neal_nl'], df['nl'], metric='r2')
print('Neal NL vs. NL: r^2 =', r2)
print('*Note: NL for Nigeria (2013) is VIIRS, while all others are DMSP')
# Out:
# Neal NL vs. NL: r^2 = 0.7804754226120915
# *Note: NL for Nigeria (2013) is VIIRS, while all others are DMSP

# %%
fig, axs = plt.subplots(1, 4, figsize=(10, 3))
i = 0
for label_col in ['label', 'neal_label']:
    for nl_col in ['neal_nl', 'nl']:
        r2 = calc_score(df[label_col], df[nl_col], metric='r2')
        df.plot.scatter(x=label_col, y=nl_col, ax=axs[i], label=f'$r^2 = {r2:.3f}$')
        axs[i].legend()
        i += 1
fig.tight_layout()

# %% [markdown]
# # KNN

# %%
def knn_nl(labels, years, nls_center, train_idxs, test_idxs, k=5):
    '''
    Args
    - labels: np.array, shape [N]
    - years: np.array, shape [N]
    - nls_center: np.array, shape [N]
    - splits: dict, split (str) => np.array
    - k: int, k for KNN
    '''
    train_nls = nls_center[train_idxs]

    # test
    test_nls = nls_center[test_idxs]
    test_labels = labels[test_idxs]
    preds = np.zeros_like(test_labels)

    knn_dmsp = sklearn.neighbors.KNeighborsRegressor(k)
    knn_viirs = sklearn.neighbors.KNeighborsRegressor(k)

    dmsp_mask = years < 2012
    viirs_mask = ~dmsp_mask

    for mask, model in [(dmsp_mask, knn_dmsp), (viirs_mask, knn_viirs)]:
        train_mask = mask[train_idxs]
        test_mask = mask[test_idxs]

        if np.sum(test_mask) == 0:
            continue

        # assign each unique NL value the same label
        u, indices = np.unique(train_nls[train_mask], return_inverse=True)
        mean_labels = np.zeros_like(u)
        for i, nl in enumerate(u):
            mean_labels[i] = np.mean(labels[nls_center == nl])

        model.fit(X=train_nls[train_mask].reshape(-1, 1), y=mean_labels[indices])
        preds[test_mask] = model.predict(X=test_nls[test_mask].reshape(-1, 1))

    return preds, knn_dmsp, knn_viirs

# %%
def knn_cv_wrapper(labels, years, nls, folds, keep=1.0, seed=None, savepath=None, verbose=False):
    '''
    Args
    - labels: np.array, shape [N]
    - years: np.array, shape [N]
    - nls: np.array, shape [N]
    - folds: dict, folds[f][split] is a np.array of indices
    - keep: float, fraction of training and validation data to use
    - seed: int, random seed
    - savepath: str, path to save predictions
    - verbose: bool, whether to print out validation performance on each fold

    Returns
    - best_models: tuple of sklearn.neighbors.KNeighborsRegressor
        best models from the last fold
    - test_preds: np.array, shape [N]
    - ks: np.array, shape [K]
    - r2s: np.array, shape [K]
    - R2s: np.array, shape [K]
    - savepath: str, path to save npz file
    '''
    N = len(labels)
    assert len(years) == N
    assert len(nls) == N
    if savepath is not None:
        assert not os.path.exists(savepath)

    test_preds = np.zeros_like(labels)
    ks = np.asarray([1, 2, 5, 10, 30, 50, 100, 200, 500, 1000])
    fold_keys = sorted(folds.keys())
    r2s = np.ones([len(fold_keys), len(ks)]) * (-np.inf)
    R2s = np.ones([len(fold_keys), len(ks)]) * (-np.inf)

    dmsp_mask = years < 2012
    viirs_mask = ~dmsp_mask

    for i, f in enumerate(fold_keys):
        if verbose:
            print(f'Runing fold {f}...')
        test_idxs = folds[f]['test']
        best_models = None

        for j, k in enumerate(ks):
            train_idxs = folds[f]['train']
            val_idxs = folds[f]['val']

            num_train = int(len(train_idxs) * keep)
            num_val = int(len(val_idxs) * keep)
            if num_train < k or num_val < k:
                print('num_train:', num_train, 'num_val:', num_train, 'k:', k)
                continue

            if keep < 1:
                if seed is not None:
                    np.random.seed(seed)
                train_idxs = np.random.choice(
                    train_idxs, size=num_train, replace=False)
                val_tfrecord_paths = np.random.choice(
                    val_idxs, size=num_val, replace=False)

            val_preds, knn_dmsp, knn_viirs = knn_nl(
                labels, years, nls, train_idxs=train_idxs,
                test_idxs=val_idxs, k=k)
            r2 = calc_score(labels=labels[val_idxs], preds=val_preds, metric='r2')
            R2 = calc_score(labels=labels[val_idxs], preds=val_preds, metric='R2')
            if R2 > np.max(R2s[i]):
                best_models = (knn_dmsp, knn_viirs)
            r2s[i, j], R2s[i, j] = r2, R2
            if verbose:
                print(f'fold={f}, k={k:4d}, val_r2={r2:0.4f}, val_R2={R2:0.4f}')

        for i, mask in enumerate([dmsp_mask, viirs_mask]):
            idxs = np.nonzero(mask)[0]
            if len(idxs) <= 0:
                continue
            test_preds[idxs] = best_models[i].predict(nls[idxs].reshape(-1, 1))

    evaluate(labels=labels, preds=test_preds, do_print=True, title='test preds')

    if savepath is not None:
        os.makedirs(os.path.dirname(savepath), exist_ok=True)
        np.savez_compressed(savepath, test_preds=test_preds, labels=labels)
        
    return best_models, test_preds, ks, r2s, R2s

def plot_knn_val_performance(nl_result, labels, title):
    '''
    Args
    - nl_result: tuple (models, ks, r2s, R2s), output of knn_cv_wrapper
    - labels: np.array
    - title: str
    '''
    _, test_preds, ks, r2s, R2s = nl_result
    fig, axs = plt.subplots(1, 2, sharey=True, figsize=(6, 3))
    for i, f in enumerate(FOLDS):
        print(f'fold {f}, chosen k:', ks[np.argmax(R2s[i])])
        axs[0].plot(ks, r2s[i], label=f'fold={f}, $r^2$')
        axs[1].plot(ks, R2s[i], label=f'fold={f}, $R^2$')
    for ax in axs:
        ax.legend()
        ax.grid()
        ax.set(xlabel='k', xscale='log')
    axs[0].set(ylabel='score')
    fig.suptitle(f'{title} validation KNN performance vs. K', y=1.02)
    fig.tight_layout()
    plt.show()

def plot_knn_test(nls_center_result, nls_mean_result, labels,
                  nl0_center_mask, nl0_mean_mask, title):
    '''
    Args
    - *_result: tuple (models, ks, r2s, R2s), output of knn_cv_wrapper
    - labels: np.array, shape [N]
    - *_mask: np.array, shape [N]
    - title: str
    '''
    fig, axs = plt.subplots(1, 2, sharey=True, figsize=(6, 3))
    results = [nls_center_result, nls_mean_result]
    nl0_masks = [nl0_center_mask, nl0_mean_mask]
    for result, nl0_mask, ax in zip(results, nl0_masks, axs):
        _, test_preds, ks, r2s, R2s = result
        scatter_preds(labels, test_preds, ax=ax)
        ax.scatter(x=labels[nl0_mask], y=test_preds[nl0_mask], c='red', s=2, label='NL = 0')
        ax.legend()
    axs[0].set_title(f'KNN on NL Center ({title})')
    axs[1].set_title(f'KNN on NL Mean ({title})')
    fig.tight_layout()
    plt.show()

# %%
# 'A': {
#     'train': np.array([1, 10, 13, ...]),
#     ...
# }
ooc_folds = {
    f: {split: [] for split in SPLITS}
    for f in FOLDS
}

for i, f in enumerate(FOLDS):
    ooc_folds[f] = {}
    test_country = DMSP_COUNTRIES[i]
    val_country = DMSP_COUNTRIES[(i+1)%4]
    train_countries = set(DMSP_COUNTRIES) - {test_country, val_country}
    ooc_folds[f]['test'] = np.nonzero((df['country'] == test_country).values)[0]
    ooc_folds[f]['val'] = np.nonzero((df['country'] == val_country).values)[0]
    ooc_folds[f]['train'] = np.nonzero(df['country'].isin(train_countries).values)[0]

# %%
DMSP0 = -MEANS['DMSP'] / STD_DEVS['DMSP']
VIIRS0 = -MEANS['VIIRS'] / STD_DEVS['VIIRS']
nl0_center_mask = ((nls_center == DMSP0) & dmsp_mask) | ((nls_center == VIIRS0) & viirs_mask)
nl0_mean_mask = ((nls_mean == DMSP0) & dmsp_mask) | ((nls_mean == VIIRS0) & viirs_mask)

# %%
country_indices = {
    country: np.nonzero((df['country'] == country).values)[0]
    for country in COUNTRIES
}

# %% [markdown]
# ## Neal OOC setup
# Choose k=100

# %%
for survey in surveys:
    country, year = survey.split('_dhs_')
    year = int(year)

    folder = os.path.join(NEAL_DIR, survey, 'data')
    image_counts = np.load(os.path.join(folder, 'cluster_image_counts.npy'))
    mask = (image_counts >= 10)

    clocs = np.load(os.path.join(folder, 'cluster_locs.npy'))
    clocs = clocs[mask]

    neal_nls = np.load(os.path.join(folder, 'cluster_nightlights.npy'))
    neal_nls = neal_nls[mask]

    neal_labels = np.load(os.path.join(folder, 'cluster_assets.npy'))
    neal_labels = neal_labels[mask]

    indices = [
        loc_to_index[(lat, lon)]
        for lat, lon in clocs.astype(np.float32)
    ]
    
    cdf = pd.DataFrame(data={
        'lat': clocs[:, 0],
        'lon': clocs[:, 1],
        'country': country,
        'year': year,
        'neal_nl': neal_nls,
        'neal_label': neal_labels,
        'nl': nls_mean[indices],
        'label': labels[indices]
    })
    df = pd.concat([df, cdf])
df.reset_index(inplace=True, drop=True)

# %%
dhs_country_row_order = ['rwanda', 'malawi', 'uganda', 'tanzania', 'nigeria']
neal_ooc_df = neal_ooc(df=df, country_order=dhs_country_row_order)
display(neal_ooc_df.style.apply(
    background_gradient, cmap='coolwarm',
    m=0.24, M=0.79,
    axis=None).format('{:.2f}'))
# Out:
# <style  type="text/css" >
#     #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row0_col0 {
#             background-color:  #bd1f2d;
#              color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row0_col1 {
#             background-color:  #c53334;
#              color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row0_col2 {
#             background-color:  #bb1b2c;
#              color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row0_col3 {
#             background-color:  #b40426;
#              color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row0_col4 {
#             background-color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row1_col0 {
#             background-color:  #f7af91;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row1_col1 {
#             background-color:  #f7ba9f;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row1_col2 {
#             background-color:  #f7b89c;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row1_col3 {
#             background-color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row1_col4 {
#             background-color:  #f1ccb8;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row2_col0 {
#             background-color:  #ec8165;
#              color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row2_col1 {
#             background-color:  #e9785d;
#              color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row2_col2 {
#             background-color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row2_col3 {
#             background-color:  #f29072;
#              color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row2_col4 {
#             background-color:  #f4c5ad;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row3_col0 {
#             background-color:  #dd5f4b;
#              color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row3_col1 {
#             background-color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row3_col2 {
#             background-color:  #f5a081;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row3_col3 {
#             background-color:  #e57058;
#              color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row3_col4 {
#             background-color:  #f2c9b4;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row4_col0 {
#             background-color:  white;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row4_col1 {
#             background-color:  #f39577;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row4_col2 {
#             background-color:  #f6bea4;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row4_col3 {
#             background-color:  #f59c7d;
#         }    #T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row4_col4 {
#             background-color:  #ead5c9;
#         }</style><table id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7" ><thead>    <tr>        <th class="index_name level0" >train_on</th>        <th class="col_heading level0 col0" >nigeria</th>        <th class="col_heading level0 col1" >tanzania</th>        <th class="col_heading level0 col2" >uganda</th>        <th class="col_heading level0 col3" >malawi</th>        <th class="col_heading level0 col4" >rwanda</th>    </tr>    <tr>        <th class="index_name level0" >eval_on</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7level0_row0" class="row_heading level0 row0" >rwanda</th>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row0_col0" class="data row0 col0" >0.78</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row0_col1" class="data row0 col1" >0.76</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row0_col2" class="data row0 col2" >0.78</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row0_col3" class="data row0 col3" >0.79</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row0_col4" class="data row0 col4" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7level0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row1_col0" class="data row1 col0" >0.62</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row1_col1" class="data row1 col1" >0.60</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row1_col2" class="data row1 col2" >0.61</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row1_col4" class="data row1 col4" >0.57</td>
#             </tr>
#             <tr>
#                         <th id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7level0_row2" class="row_heading level0 row2" >uganda</th>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row2_col0" class="data row2 col0" >0.68</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row2_col1" class="data row2 col1" >0.69</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row2_col3" class="data row2 col3" >0.67</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row2_col4" class="data row2 col4" >0.58</td>
#             </tr>
#             <tr>
#                         <th id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7level0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row3_col0" class="data row3 col0" >0.72</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row3_col1" class="data row3 col1" >nan</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row3_col2" class="data row3 col2" >0.64</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row3_col3" class="data row3 col3" >0.70</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row3_col4" class="data row3 col4" >0.57</td>
#             </tr>
#             <tr>
#                         <th id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7level0_row4" class="row_heading level0 row4" >nigeria</th>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row4_col0" class="data row4 col0" >nan</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row4_col1" class="data row4 col1" >0.66</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row4_col2" class="data row4 col2" >0.60</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row4_col3" class="data row4 col3" >0.65</td>
#                         <td id="T_45e13f0a_8786_11e9_beba_83cd8f8b7bd7row4_col4" class="data row4 col4" >0.54</td>
#             </tr>
#     </tbody></table>

# %%
neal_original_df = pd.DataFrame(data=[
    [.55, .68, .66, .59, .75],
    [.40, .42, .43, .55, .42],
    [.56, .61, .66, .55, .56],
    [.43, .58, .51, .40, .47],
    [.69, .50, .46, .24, .39],
], index=dhs_country_row_order, columns=dhs_country_row_order[::-1])
neal_original_df.index.name = 'eval_on'
neal_original_df.columns.name = 'train_on'
display(neal_original_df.style.apply(
    background_gradient,
    m=0.24, M=0.79,
    cmap='coolwarm', axis=None))
# Out:
# <style  type="text/css" >
#     #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row0_col0 {
#             background-color:  #ecd3c5;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row0_col1 {
#             background-color:  #ee8468;
#              color:  white;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row0_col2 {
#             background-color:  #f39475;
#              color:  white;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row0_col3 {
#             background-color:  #f5c1a9;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row0_col4 {
#             background-color:  #cd423b;
#              color:  white;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row1_col0 {
#             background-color:  #9bbcff;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row1_col1 {
#             background-color:  #a7c5fe;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row1_col2 {
#             background-color:  #aec9fc;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row1_col3 {
#             background-color:  #ecd3c5;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row1_col4 {
#             background-color:  #a7c5fe;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row2_col0 {
#             background-color:  #efcfbf;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row2_col1 {
#             background-color:  #f7b599;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row2_col2 {
#             background-color:  #f39475;
#              color:  white;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row2_col3 {
#             background-color:  #ecd3c5;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row2_col4 {
#             background-color:  #efcfbf;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row3_col0 {
#             background-color:  #aec9fc;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row3_col1 {
#             background-color:  #f4c6af;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row3_col2 {
#             background-color:  #dadce0;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row3_col3 {
#             background-color:  #9bbcff;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row3_col4 {
#             background-color:  #c6d6f1;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row4_col0 {
#             background-color:  #ea7b60;
#              color:  white;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row4_col1 {
#             background-color:  #d6dce4;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row4_col2 {
#             background-color:  #c0d4f5;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row4_col3 {
#             background-color:  #3b4cc0;
#              color:  white;
#         }    #T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row4_col4 {
#             background-color:  #94b6ff;
#         }</style><table id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7" ><thead>    <tr>        <th class="index_name level0" >train_on</th>        <th class="col_heading level0 col0" >nigeria</th>        <th class="col_heading level0 col1" >tanzania</th>        <th class="col_heading level0 col2" >uganda</th>        <th class="col_heading level0 col3" >malawi</th>        <th class="col_heading level0 col4" >rwanda</th>    </tr>    <tr>        <th class="index_name level0" >eval_on</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7level0_row0" class="row_heading level0 row0" >rwanda</th>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row0_col0" class="data row0 col0" >0.55</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row0_col1" class="data row0 col1" >0.68</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row0_col2" class="data row0 col2" >0.66</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row0_col3" class="data row0 col3" >0.59</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row0_col4" class="data row0 col4" >0.75</td>
#             </tr>
#             <tr>
#                         <th id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7level0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row1_col0" class="data row1 col0" >0.4</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row1_col1" class="data row1 col1" >0.42</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row1_col2" class="data row1 col2" >0.43</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row1_col3" class="data row1 col3" >0.55</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row1_col4" class="data row1 col4" >0.42</td>
#             </tr>
#             <tr>
#                         <th id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7level0_row2" class="row_heading level0 row2" >uganda</th>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row2_col0" class="data row2 col0" >0.56</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row2_col1" class="data row2 col1" >0.61</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row2_col2" class="data row2 col2" >0.66</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row2_col3" class="data row2 col3" >0.55</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row2_col4" class="data row2 col4" >0.56</td>
#             </tr>
#             <tr>
#                         <th id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7level0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row3_col0" class="data row3 col0" >0.43</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row3_col1" class="data row3 col1" >0.58</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row3_col2" class="data row3 col2" >0.51</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row3_col3" class="data row3 col3" >0.4</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row3_col4" class="data row3 col4" >0.47</td>
#             </tr>
#             <tr>
#                         <th id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7level0_row4" class="row_heading level0 row4" >nigeria</th>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row4_col0" class="data row4 col0" >0.69</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row4_col1" class="data row4 col1" >0.5</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row4_col2" class="data row4 col2" >0.46</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row4_col3" class="data row4 col3" >0.24</td>
#                         <td id="T_5c28d322_8786_11e9_beba_83cd8f8b7bd7row4_col4" class="data row4 col4" >0.39</td>
#             </tr>
#     </tbody></table>

# %%
concat_df = pd.concat(
    [neal_ooc_df, neal_original_df],
    keys=['KNN on scalar NL', 'Science paper'])
display(concat_df.style.apply(
    background_gradient, cmap='coolwarm',
    m=0.24, M=0.79,
    axis=None).format('{:.2f}'))
# Out:
# <style  type="text/css" >
#     #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row0_col0 {
#             background-color:  #bd1f2d;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row0_col1 {
#             background-color:  #c53334;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row0_col2 {
#             background-color:  #bb1b2c;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row0_col3 {
#             background-color:  #b40426;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row0_col4 {
#             background-color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row1_col0 {
#             background-color:  #f7af91;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row1_col1 {
#             background-color:  #f7ba9f;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row1_col2 {
#             background-color:  #f7b89c;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row1_col3 {
#             background-color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row1_col4 {
#             background-color:  #f1ccb8;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row2_col0 {
#             background-color:  #ec8165;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row2_col1 {
#             background-color:  #e9785d;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row2_col2 {
#             background-color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row2_col3 {
#             background-color:  #f29072;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row2_col4 {
#             background-color:  #f4c5ad;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row3_col0 {
#             background-color:  #dd5f4b;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row3_col1 {
#             background-color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row3_col2 {
#             background-color:  #f5a081;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row3_col3 {
#             background-color:  #e57058;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row3_col4 {
#             background-color:  #f2c9b4;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row4_col0 {
#             background-color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row4_col1 {
#             background-color:  #f39577;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row4_col2 {
#             background-color:  #f6bea4;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row4_col3 {
#             background-color:  #f59c7d;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row4_col4 {
#             background-color:  #ead5c9;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row5_col0 {
#             background-color:  #ecd3c5;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row5_col1 {
#             background-color:  #ee8468;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row5_col2 {
#             background-color:  #f39475;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row5_col3 {
#             background-color:  #f5c1a9;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row5_col4 {
#             background-color:  #cd423b;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row6_col0 {
#             background-color:  #9bbcff;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row6_col1 {
#             background-color:  #a7c5fe;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row6_col2 {
#             background-color:  #aec9fc;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row6_col3 {
#             background-color:  #ecd3c5;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row6_col4 {
#             background-color:  #a7c5fe;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row7_col0 {
#             background-color:  #efcfbf;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row7_col1 {
#             background-color:  #f7b599;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row7_col2 {
#             background-color:  #f39475;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row7_col3 {
#             background-color:  #ecd3c5;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row7_col4 {
#             background-color:  #efcfbf;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row8_col0 {
#             background-color:  #aec9fc;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row8_col1 {
#             background-color:  #f4c6af;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row8_col2 {
#             background-color:  #dadce0;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row8_col3 {
#             background-color:  #9bbcff;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row8_col4 {
#             background-color:  #c6d6f1;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row9_col0 {
#             background-color:  #ea7b60;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row9_col1 {
#             background-color:  #d6dce4;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row9_col2 {
#             background-color:  #c0d4f5;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row9_col3 {
#             background-color:  #3b4cc0;
#              color:  white;
#         }    #T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row9_col4 {
#             background-color:  #94b6ff;
#         }</style><table id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >train_on</th>        <th class="col_heading level0 col0" >nigeria</th>        <th class="col_heading level0 col1" >tanzania</th>        <th class="col_heading level0 col2" >uganda</th>        <th class="col_heading level0 col3" >malawi</th>        <th class="col_heading level0 col4" >rwanda</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="index_name level1" >eval_on</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7level0_row0" class="row_heading level0 row0" rowspan=5>KNN on scalar NL</th>
#                         <th id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7level1_row0" class="row_heading level1 row0" >rwanda</th>
#                         <td id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row0_col0" class="data row0 col0" >0.78</td>
#                         <td id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row0_col1" class="data row0 col1" >0.76</td>
#                         <td id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row0_col2" class="data row0 col2" >0.78</td>
#                         <td id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row0_col3" class="data row0 col3" >0.79</td>
#                         <td id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row0_col4" class="data row0 col4" >nan</td>
#             </tr>
#             <tr>
#                                 <th id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7level1_row1" class="row_heading level1 row1" >malawi</th>
#                         <td id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row1_col0" class="data row1 col0" >0.62</td>
#                         <td id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row1_col1" class="data row1 col1" >0.60</td>
#                         <td id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row1_col2" class="data row1 col2" >0.61</td>
#                         <td id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_5f3b5f1c_8786_11e9_beba_83cd8f8b7bd7row1_col4" class="data row1 col4" >0.57</td>

# %% [markdown]
# ## Label vs. NL

# %%
nls_mean_result = knn_cv_wrapper(
    labels=df['label'].values, years=df['year'].values, nls=df['nl'].values, folds=ooc_folds,
    savepath=None)
test_preds = nls_mean_result[1]
for country in COUNTRIES:
    indices = country_indices[country]
    evaluate(labels=df.loc[indices, 'label'], preds=test_preds[indices], do_print=True, title=country)
# Out:
# num_train: 848 num_val: 848 k: 500
# num_train: 848 num_val: 848 k: 1000
# num_train: 1220 num_val: 1220 k: 500
# num_train: 1220 num_val: 1220 k: 1000
# num_train: 1319 num_val: 1319 k: 500
# num_train: 1319 num_val: 1319 k: 1000
# num_train: 947 num_val: 947 k: 1000
# test preds	- r^2: 0.641, R^2: 0.581, mse: 0.133, rank: 0.650
# malawi	- r^2: 0.559, R^2: 0.547, mse: 0.104, rank: 0.590
# rwanda	- r^2: 0.717, R^2: 0.664, mse: 0.083, rank: 0.555
# tanzania	- r^2: 0.633, R^2: 0.512, mse: 0.206, rank: 0.759
# uganda	- r^2: 0.723, R^2: 0.593, mse: 0.172, rank: 0.752

# %%
plot_knn_val_performance(nls_mean_result, df['label'].values, title='NL mean')
# Out:
# fold A, chosen k: 100
# fold B, chosen k: 30
# fold C, chosen k: 30
# fold D, chosen k: 200

# %%
plt.scatter(df['label'], test_preds, c=df['country'].map(COUNTRIES.index), cmap='tab10')

# %% [markdown]
# ## Neal Label vs. Neal NL

# %%
nls_mean_result = knn_cv_wrapper(
    labels=df['neal_label'].values, years=df['year'].values, nls=df['neal_nl'].values, folds=ooc_folds,
    savepath=None)
test_preds = nls_mean_result[1]
for country in COUNTRIES:
    indices = country_indices[country]
    evaluate(labels=df.loc[indices, 'neal_label'], preds=test_preds[indices], do_print=True, title=country)
# Out:
# num_train: 848 num_val: 848 k: 500
# num_train: 848 num_val: 848 k: 1000
# num_train: 1220 num_val: 1220 k: 500
# num_train: 1220 num_val: 1220 k: 1000
# num_train: 1319 num_val: 1319 k: 500
# num_train: 1319 num_val: 1319 k: 1000
# num_train: 947 num_val: 947 k: 1000
# test preds	- r^2: 0.673, R^2: 0.671, mse: 0.232, rank: 0.636
# malawi	- r^2: 0.616, R^2: 0.601, mse: 0.265, rank: 0.579
# rwanda	- r^2: 0.793, R^2: 0.764, mse: 0.164, rank: 0.485
# tanzania	- r^2: 0.701, R^2: 0.700, mse: 0.212, rank: 0.752
# uganda	- r^2: 0.665, R^2: 0.656, mse: 0.270, rank: 0.712

# %%
plot_knn_val_performance(nls_mean_result, labels, title='NL mean')
# Out:
# fold A, chosen k: 30
# fold B, chosen k: 100
# fold C, chosen k: 200
# fold D, chosen k: 100

# %%
plt.scatter(df['neal_label'], test_preds, c=df['country'].map(COUNTRIES.index), cmap='tab10')

# %% [markdown]
# ## Neal Label vs. NL

# %%
nls_mean_result = knn_cv_wrapper(
    labels=df['neal_label'].values, years=df['year'].values, nls=df['nl'].values, folds=ooc_folds,
    savepath=None)
test_preds = nls_mean_result[1]
for country in COUNTRIES:
    indices = country_indices[country]
    evaluate(labels=df.loc[indices, 'neal_label'], preds=test_preds[indices], do_print=True, title=country)
# Out:
# num_train: 848 num_val: 848 k: 500
# num_train: 848 num_val: 848 k: 1000
# num_train: 1220 num_val: 1220 k: 500
# num_train: 1220 num_val: 1220 k: 1000
# num_train: 1319 num_val: 1319 k: 500
# num_train: 1319 num_val: 1319 k: 1000
# num_train: 947 num_val: 947 k: 1000
# test preds	- r^2: 0.662, R^2: 0.657, mse: 0.242, rank: 0.655
# malawi	- r^2: 0.592, R^2: 0.581, mse: 0.278, rank: 0.600
# rwanda	- r^2: 0.775, R^2: 0.769, mse: 0.161, rank: 0.498
# tanzania	- r^2: 0.699, R^2: 0.691, mse: 0.219, rank: 0.757
# uganda	- r^2: 0.682, R^2: 0.629, mse: 0.291, rank: 0.736

# %%
plot_knn_val_performance(nls_mean_result, labels, title='NL mean')
# Out:
# fold A, chosen k: 50
# fold B, chosen k: 50
# fold C, chosen k: 200
# fold D, chosen k: 30

# %%
plt.scatter(df['neal_label'], test_preds, c=df['country'].map(COUNTRIES.index), cmap='tab10')
