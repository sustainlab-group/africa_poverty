# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports-+-Constants" data-toc-modified-id="Imports-+-Constants-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports + Constants</a></span></li><li><span><a href="#Create-histogram-diffs" data-toc-modified-id="Create-histogram-diffs-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Create histogram diffs</a></span><ul class="toc-item"><li><span><a href="#Load-saved-histograms" data-toc-modified-id="Load-saved-histograms-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Load saved histograms</a></span></li><li><span><a href="#Split-NL-band" data-toc-modified-id="Split-NL-band-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Split NL band</a></span></li><li><span><a href="#Load-pairs" data-toc-modified-id="Load-pairs-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Load pairs</a></span></li><li><span><a href="#Diff-the-histograms" data-toc-modified-id="Diff-the-histograms-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Diff the histograms</a></span></li><li><span><a href="#Augment-the-diffs" data-toc-modified-id="Augment-the-diffs-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Augment the diffs</a></span></li><li><span><a href="#Standardize-the-diffs" data-toc-modified-id="Standardize-the-diffs-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Standardize the diffs</a></span></li></ul></li><li><span><a href="#OOC-Histogram-Baseline" data-toc-modified-id="OOC-Histogram-Baseline-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>OOC Histogram Baseline</a></span><ul class="toc-item"><li><span><a href="#Change-in-NL" data-toc-modified-id="Change-in-NL-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Change in NL</a></span></li><li><span><a href="#Delta-of-index" data-toc-modified-id="Delta-of-index-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Delta of index</a></span></li><li><span><a href="#Index-of-Delta" data-toc-modified-id="Index-of-Delta-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Index of Delta</a></span></li></ul></li><li><span><a href="#Incountry-Baselines" data-toc-modified-id="Incountry-Baselines-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Incountry Baselines</a></span><ul class="toc-item"><li><span><a href="#Load-Folds" data-toc-modified-id="Load-Folds-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Load Folds</a></span></li><li><span><a href="#Predict-Country-Mean" data-toc-modified-id="Predict-Country-Mean-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Predict Country Mean</a></span></li><li><span><a href="#Predict-Fold-Mean" data-toc-modified-id="Predict-Fold-Mean-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Predict Fold Mean</a></span></li><li><span><a href="#Histogram-Baseline" data-toc-modified-id="Histogram-Baseline-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Histogram Baseline</a></span></li><li><span><a href="#Single-Model" data-toc-modified-id="Single-Model-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Single Model</a></span></li></ul></li></ul></div>

# %% [markdown]
# This notebook assumes that `models/baselines_lsms.ipynb` has already been run.

# %% [markdown]
# # Imports + Constants

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys

import matplotlib.pyplot as plt
import numpy as np
import pickle
import pandas as pd
import seaborn as sns

sys.path.append('../')
from models.histograms import split_nl_hist
from models.linear_model import train_linear_model, train_linear_logo
from utils.analysis import (
    calc_score,
    evaluate,
    evaluate_df,
    sorted_scores,
    plot_label_vs_score)
from utils.general import colordisplay, load_npz
from utils.plot import scatter_preds

# %%
SPLITS = ['train', 'val', 'test']
FOLDS = ['A', 'B', 'C', 'D', 'E']

LSMS_COUNTRIES = ['ethiopia', 'malawi', 'nigeria', 'tanzania', 'uganda']

# %% [markdown]
# # Create histogram diffs

# %%
# BAND_BIN_EDGES = [-10^5, -5.0, -4.9, -4.8, ..., 4.8, 4.9, 5.0, 10^5]
# BAND_BIN_CENTERS = [-5.05, -4.95, -4.85, ..., 4.85, 4.95, 5.05]
BAND_BIN_EDGES = np.concatenate([
    [-1e5],
    np.arange(-5.0, 5.1, 0.1),
    [1e5]
])
BAND_BIN_CENTERS = np.arange(-5.05, 5.15, 0.1)

# LABEL_BIN_EDGES = [-2.0, -1.9, ..., 2.8, 2.9]
# LABEL_BIN_CENTERS = [-1.95, -1.85, ..., 2.75, 2.85]
LABEL_BIN_EDGES = np.arange(-2.0, 3.0, 0.1)
LABEL_BIN_CENTERS = np.arange(-1.95, 2.95, 0.1)

# band name => color for plotting
BAND_COLORS = {
    'BLUE'  : 'blue',
    'GREEN' : 'green',
    'RED'   : 'red',
    'SWIR1' : 'purple',
    'SWIR2' : 'brown',
    'TEMP1' : 'orange',
    'NIR'   : 'pink',
    'NIGHTLIGHTS': 'black',
    'DMSP'  : 'black',
    'VIIRS' : 'gray',
}
BAND_ORDER = ['BLUE', 'GREEN', 'RED', 'SWIR1', 'SWIR2', 'TEMP1', 'NIR', 'NIGHTLIGHTS']
BAND_ORDER_NLSPLIT = ['BLUE', 'GREEN', 'RED', 'SWIR1', 'SWIR2', 'TEMP1', 'NIR', 'DMSP', 'VIIRS']

BANDS_DICT = {
    'rgb': [0, 1, 2],
    'rgbnl': [0, 1, 2, 7, 8],
    'ms': [0, 1, 2, 3, 4, 5, 6],
    'msnl': [0, 1, 2, 3, 4, 5, 6, 7, 8],
    'nl': [7, 8],
}

# %% [markdown]
# ## Load saved histograms

# %%
result = load_npz('../data/lsms_image_hists.npz')
image_hists = result['image_hists']
years = result['years']
nls_center = result['nls_center']
nls_mean = result['nls_mean']
# Out:
# image_hists: dtype=int64, shape=(3020, 8, 102)
# labels: dtype=float32, shape=(3020,)
# locs: dtype=float32, shape=(3020, 2)
# years: dtype=int32, shape=(3020,)
# nls_center: dtype=float32, shape=(3020,)
# nls_mean: dtype=float32, shape=(3020,)

# %% [markdown]
# ## Split NL band

# %%
image_hists = split_nl_hist(image_hists, years)

# %% [markdown]
# ## Load pairs

# %%
file_path = '../data/lsmsdelta_pairs.csv'
delta_pairs_df = pd.read_csv(file_path, index_col=False)
delta_pairs_df.rename({
    'index': 'deltaofindex',
    'index_diff': 'indexofdelta',
    'x': 'households'
}, axis=1, inplace=True)
with pd.option_context('display.max_rows', 4):
    display(delta_pairs_df)
npairs = len(delta_pairs_df)

country_labels = np.asarray(list(map(LSMS_COUNTRIES.index, delta_pairs_df['country'])))
country_indices = {
    country: np.where(delta_pairs_df['country'] == country)[0]
    for country in LSMS_COUNTRIES
}
# Out:
#            lat        lon  year.x   country  year.y  deltaofindex  \
# 0    -0.292248  31.478722    2005    uganda    2009     -0.369128
# 1    -0.292248  31.478722    2009    uganda    2013     -0.047140
# ...        ...        ...     ...       ...     ...           ...
# 1537  9.917938  11.689417    2010   nigeria    2015      0.700611
# 1538  9.991906  37.692553    2011  ethiopia    2015      0.072652
#
#       indexofdelta geolev1 geolev2  households  tfrecords_index.x  \
# 0        -1.782208  UGA.53     UGA           8               2574
# 1        -0.119516  UGA.53     UGA           8               2694
# ...            ...     ...     ...         ...                ...
# 1537      0.777255  NGA.16     NGA           1               1145
# 1538      0.049075   ETH.3     ETH           9                120
#
#       tfrecords_index.y
# 0                  2694
# 1                  2941
# ...                 ...
# 1537               1626
# 1538                449
#
# [1539 rows x 12 columns]

# %% [markdown]
# ## Diff the histograms

# %%
labels_doi = delta_pairs_df['deltaofindex'].values
labels_iod = delta_pairs_df['indexofdelta'].values
weights = delta_pairs_df['households'].values * len(delta_pairs_df) /delta_pairs_df['households'].sum()

index1 = delta_pairs_df['tfrecords_index.x'].values
index2 = delta_pairs_df['tfrecords_index.y'].values
hists_diffs = image_hists[index1] - image_hists[index2]
nls_mean_diffs = nls_mean[index2] - nls_mean[index1]
nls_center_diffs = nls_center[index2] - nls_center[index1]

labels_doi_classes = np.ones_like(labels_doi, dtype=np.int32)
labels_doi_classes[labels_doi < -0.125] = 0
labels_doi_classes[labels_doi > 0.125] = 2

labels_iod_classes = np.ones_like(labels_iod, dtype=np.int32)
labels_iod_classes[labels_iod < -0.5] = 0
labels_iod_classes[labels_iod > 0.5] = 2

# %% [markdown]
# ## Augment the diffs

# %%
# augment the diffs
hists_diffs_aug = np.concatenate([hists_diffs, -hists_diffs])
nls_mean_diffs_aug = np.concatenate([nls_mean_diffs, -nls_mean_diffs])
nls_center_diffs_aug = np.concatenate([nls_center_diffs, -nls_center_diffs])
labels_doi_aug = np.concatenate([labels_doi, -labels_doi])
labels_iod_aug = np.concatenate([labels_iod, -labels_iod])
weights_aug = np.tile(weights, 2)
country_labels_aug = np.tile(country_labels, 2)
country_indices_aug = {c: np.tile(indices, 2) for c, indices in country_indices.items()}

# %% [markdown]
# ## Standardize the diffs

# %%
hists_diffs_mean = np.mean(hists_diffs_aug, axis=0, dtype=np.float64)
hists_diffs_std = np.std(hists_diffs_aug, axis=0, dtype=np.float64)
standardized_hists_diffs = (hists_diffs_aug - hists_diffs_mean) / (hists_diffs_std + 1e-6)
print(standardized_hists_diffs.shape)
# Out:
# (3078, 9, 102)

# %% [markdown]
# # OOC Histogram Baseline

# %%
def run_ooc(country, band_indices, labels_diffs_aug):
    test_group = LSMS_COUNTRIES.index(country)
    test_preds, coefs, intercept = train_linear_logo(
        features=standardized_hists_diffs[:, band_indices, :].reshape(npairs*2, -1),
        labels=labels_diffs_aug,
        group_labels=country_labels_aug,
        cv_groups=[i for i in range(len(LSMS_COUNTRIES)) if test_group != i],
        test_groups=[test_group],
        weights=weights_aug,
        plot=False, group_names=LSMS_COUNTRIES, return_weights=True)
    print(f'best intercept: {intercept:.4g}')
    return evaluate(test_preds, labels_diffs_aug[country_indices_aug[country]], do_print=True)

# %% [markdown]
# ## Change in NL

# %%
# limit to Uganda 2005-09 only, where we have DMSP for both
uganda0509_mask = (
    (delta_pairs_df['year.x'] == 2005) &
    (delta_pairs_df['year.y'] == 2009) &
    (delta_pairs_df['country'] == 'uganda'))
delta_nls_center = nls_center[index1[uganda0509_mask]] - nls_center[index2[uganda0509_mask]]
delta_nls_mean = nls_mean[index1[uganda0509_mask]] - nls_mean[index2[uganda0509_mask]]
nls_weights = weights[uganda0509_mask]

# %%
r2_doi_nls_center = calc_score(labels_doi[uganda0509_mask], delta_nls_center, weights=nls_weights, metric='r2')
r2_doi_nls_mean = calc_score(labels_doi[uganda0509_mask], delta_nls_mean, weights=nls_weights, metric='r2')

fig, axs = plt.subplots(1, 2, sharey=True, figsize=(5, 3))
axs[0].scatter(labels_doi[uganda0509_mask], delta_nls_center, s=nls_weights*5,
               label=f'weighted $r^2$ = {r2_doi_nls_center:.2f}')
axs[1].scatter(labels_doi[uganda0509_mask], delta_nls_mean, s=nls_weights*5,
               label=f'weighted $r^2$ = {r2_doi_nls_mean:.2f}')
axs[0].set(xlabel='label (delta-of-index)', ylabel='$\Delta$ NL center')
axs[1].set(xlabel='label (delta-of-index)', ylabel='$\Delta$ NL mean')
for ax in axs:
    ax.legend()
    ax.grid(True)
fig.suptitle('Uganda 2005-09', y=1.01)
fig.tight_layout()
plt.show()

# %%
r2_iod_nls_center = calc_score(labels_iod[uganda0509_mask], delta_nls_center, weights=nls_weights, metric='r2')
r2_iod_nls_mean = calc_score(labels_iod[uganda0509_mask], delta_nls_mean, weights=nls_weights, metric='r2')

fig, axs = plt.subplots(1, 2, sharey=True, figsize=(5, 3))
axs[0].scatter(labels_iod[uganda0509_mask], delta_nls_center, s=nls_weights*5,
               label=f'weighted $r^2$ = {r2_iod_nls_center:.2f}')
axs[1].scatter(labels_iod[uganda0509_mask], delta_nls_mean, s=nls_weights*5,
               label=f'weighted $r^2$ = {r2_iod_nls_mean:.2f}')
axs[0].set(xlabel='label (index-of-delta)', ylabel='$\Delta$ NL center')
axs[1].set(xlabel='label (index-of-delta)', ylabel='$\Delta$ NL mean')
for ax in axs:
    ax.legend()
    ax.grid(True)
fig.suptitle('Uganda 2005-09', y=1.01)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Delta of index

# %%
rgb_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
rgb_df.set_index('country', inplace=True)
for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    rgb_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['rgb'],
                                     labels_diffs_aug=labels_doi_aug)
display(rgb_df)
# Out:
# === ethiopia ===
# best val mse: 0.103, best alpha: 8192.0, test mse: 0.053
# best intercept: -6.156e-18
# r^2: 0.000, R^2: -49.071, mse: 0.063, rank: 0.000
# === malawi ===
# best val mse: 0.099, best alpha: 1024.0, test mse: 0.020
# best intercept: -2.692e-18
# r^2: 0.000, R^2: -6.350, mse: 0.027, rank: 0.000
# === nigeria ===
# best val mse: 0.060, best alpha: 1024.0, test mse: 0.153
# best intercept: -1.151e-17
# r^2: 0.000, R^2: -7.016, mse: 0.225, rank: 0.000
# === tanzania ===
# best val mse: 0.084, best alpha: 1024.0, test mse: 0.108
# best intercept: 4.861e-18
# r^2: 0.000, R^2: -20.646, mse: 0.128, rank: 0.000
# === uganda ===
# best val mse: 0.089, best alpha: 1024.0, test mse: 0.080
# best intercept: -1.068e-18
# r^2: 0.000, R^2: -43.605, mse: 0.100, rank: 0.000
#                     r2         R2       mse  rank
# country
# ethiopia  2.685191e-35 -49.070991  0.062541   0.0
# malawi    0.000000e+00  -6.350232  0.026927   0.0
# nigeria   0.000000e+00  -7.015872  0.225233   0.0
# tanzania  1.225737e-35 -20.645716  0.127731   0.0
# uganda    1.286225e-34 -43.604845  0.100393   0.0

# %%
msnl_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
msnl_df.set_index('country', inplace=True)
for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    msnl_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['msnl'],
                                      labels_diffs_aug=labels_doi_aug)
display(msnl_df)
# Out:
# === ethiopia ===
# best val mse: 0.103, best alpha: 65536.0, test mse: 0.054
# best intercept: 8.482e-19
# r^2: 0.000, R^2: -111.068, mse: 0.062, rank: 0.000
# === malawi ===
# best val mse: 0.100, best alpha: 8192.0, test mse: 0.021
# best intercept: 1.175e-17
# r^2: 0.000, R^2: -3.278, mse: 0.030, rank: 0.000
# === nigeria ===
# best val mse: 0.061, best alpha: 8192.0, test mse: 0.153
# best intercept: 3.098e-18
# r^2: 0.000, R^2: -38.164, mse: 0.202, rank: 0.000
# === tanzania ===
# best val mse: 0.084, best alpha: 8192.0, test mse: 0.107
# best intercept: -3.133e-19
# r^2: 0.000, R^2: -15.035, mse: 0.130, rank: 0.000
# === uganda ===
# best val mse: 0.089, best alpha: 8192.0, test mse: 0.079
# best intercept: 9.472e-18
# r^2: 0.000, R^2: -59.130, mse: 0.100, rank: 0.000

# %% [markdown]
# ## Index of Delta

# %%
rgb_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
rgb_df.set_index('country', inplace=True)
for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    rgb_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['rgb'],
                                     labels_diffs_aug=labels_iod_aug)
display(rgb_df)
# Out:
# === ethiopia ===
# best val mse: 0.517, best alpha: 65536.0, test mse: 0.159
# best intercept: -1.871e-17
# r^2: 0.000, R^2: -300.707, mse: 0.174, rank: 0.000
# === malawi ===
# best val mse: 0.476, best alpha: 65536.0, test mse: 0.063
# best intercept: -2.069e-17
# r^2: 0.000, R^2: -213.865, mse: 0.073, rank: 0.000
# === nigeria ===
# best val mse: 0.398, best alpha: 8192.0, test mse: 0.452
# best intercept: -1.003e-17
# r^2: 0.000, R^2: -27.008, mse: 0.561, rank: 0.000
# === tanzania ===
# best val mse: 0.433, best alpha: 65536.0, test mse: 0.229
# best intercept: 5.681e-18
# r^2: 0.000, R^2: -215.629, mse: 0.316, rank: 0.000
# === uganda ===
# best val mse: 0.249, best alpha: 8192.0, test mse: 1.095
# best intercept: -6.074e-18
# r^2: 0.000, R^2: -592.164, mse: 1.164, rank: 0.000
#                     r2          R2       mse  rank
# country
# ethiopia  2.485616e-34 -300.706596  0.174212   0.0
# malawi    0.000000e+00 -213.864953  0.073034   0.0
# nigeria   2.481875e-35  -27.007505  0.561268   0.0
# tanzania  1.888693e-35 -215.628736  0.315509   0.0
# uganda    0.000000e+00 -592.163502  1.164130   0.0

# %%
msnl_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
msnl_df.set_index('country', inplace=True)
for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    msnl_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['msnl'],
                                      labels_diffs_aug=labels_iod_aug)
display(msnl_df)
# Out:
# === ethiopia ===
# best val mse: 0.516, best alpha: 65536.0, test mse: 0.157
# best intercept: -1.783e-17
# r^2: 0.000, R^2: -136.761, mse: 0.175, rank: 0.000
# === malawi ===
# best val mse: 0.476, best alpha: 65536.0, test mse: 0.058
# best intercept: -1.424e-17
# r^2: 0.000, R^2: -9.607, mse: 0.080, rank: 0.000
# === nigeria ===
# best val mse: 0.402, best alpha: 65536.0, test mse: 0.442
# best intercept: -2.777e-18
# r^2: 0.000, R^2: -154.206, mse: 0.545, rank: 0.000
# === tanzania ===
# best val mse: 0.432, best alpha: 65536.0, test mse: 0.230
# best intercept: 5.409e-18
# r^2: 0.000, R^2: -76.567, mse: 0.318, rank: 0.000
# === uganda ===
# best val mse: 0.249, best alpha: 65536.0, test mse: 1.100
# best intercept: 1.867e-18
# r^2: 0.000, R^2: -1223.195, mse: 1.163, rank: 0.000
#                     r2           R2       mse  rank
# country
# ethiopia  8.305410e-35  -136.761421  0.174905   0.0
# malawi    2.121059e-35    -9.607446  0.080261   0.0
# nigeria   3.542724e-35  -154.206227  0.544738   0.0
# tanzania  0.000000e+00   -76.567422  0.318154   0.0
# uganda    0.000000e+00 -1223.194643  1.163117   0.0

# %% [markdown]
# # Incountry Baselines

# %% [markdown]
# ## Load Folds

# %%
with open('../data/lsms_incountry_folds.pkl', 'rb') as f:
    incountry_folds = pickle.load(f)

# %%
incountry_group_labels_aug = np.zeros(npairs * 2, dtype=np.int32)

for i, f in enumerate(FOLDS):
    fold_mask = delta_pairs_df[['index1', 'index2']].isin(incountry_folds[f]['test']).values
    assert np.all(fold_mask[:, 0] == fold_mask[:, 1])
    fold_mask = np.tile(fold_mask[:, 0], 2)
    incountry_group_labels_aug[fold_mask] = i

# %% [markdown]
# ## Predict Country Mean

# %%
mean_preds = np.zeros(npairs)
for i, country in enumerate(LSMS_COUNTRIES):
    indices = np.where(country_labels == i)[0]
    mean_preds[indices] = np.mean(labels_diffs[indices])
r2, R2, mse, rank = evaluate(labels_diffs, mean_preds, do_print=True)
# Out:
# r^2: 0.204, R^2: 0.204, mse: 0.108, rank: 0.441

# %%
df = pd.DataFrame({
    'labels': labels_diffs,
    'preds': mean_preds,
    'country': np.asarray(LSMS_COUNTRIES)[country_labels]
})
fig, ax = plt.subplots(1, 1, figsize=[5, 5], constrained_layout=True)
m, b = np.polyfit(df['labels'], df['preds'], 1)
ax.plot([-2.3, 2.3], [-2.3, 2.3], '-y')
sns.scatterplot(data=df, x='labels', y='preds', hue='country', ax=ax)
ax.plot(df['labels'], m*df['labels']+b, ':k', label=f'$r^2={r2:.3g}$')
ax.set_aspect('equal')
ax.legend()
ax.grid(True)

# %%
for i, country in enumerate(LSMS_COUNTRIES):
    class_counts = np.zeros(3)
    indices = np.where(country_labels == i)[0]
    for j in [0, 1, 2]:
        class_counts[j] = np.sum(labels_diffs_classes[indices] == j)
    normalized_class_counts = class_counts / class_counts.sum()
    print(country, np.argmax(normalized_class_counts), np.max(normalized_class_counts))
# Out:
# ethiopia 1 0.4801223241590214
# malawi 1 0.6274509803921569
# nigeria 2 0.6208333333333333
# tanzania 0 0.5975232198142415
# uganda 0 0.37298387096774194

# %% [markdown]
# ## Predict Fold Mean

# %%
mean_preds = np.zeros(npairs)
fold_labels = np.full(shape=npairs, fill_value='_')
for i, f in enumerate(FOLDS):
    fold_mask = delta_pairs_df['index1'].isin(incountry_folds[f]['test']).values
    fold_labels[fold_mask] = f
    mean_preds[fold_mask] = np.mean(labels_diffs[fold_mask])
r2, R2, mse, rank = evaluate(labels_diffs[:npairs], mean_preds, do_print=True)
# Out:
# r^2: 0.005, R^2: 0.005, mse: 0.135, rank: 0.047

# %%
df = pd.DataFrame({
    'labels': labels_diffs,
    'preds': mean_preds,
    'fold': fold_labels,
})
fig, ax = plt.subplots(1, 1, figsize=[5, 5], constrained_layout=True)
m, b = np.polyfit(df['labels'], df['preds'], 1)
ax.plot([-2.3, 2.3], [-2.3, 2.3], '-y')
sns.scatterplot(data=df, x='labels', y='preds', hue='fold', ax=ax)
ax.plot(df['labels'], m*df['labels']+b, ':k', label=f'$r^2={r2:.3g}$')
ax.set_aspect('equal')
ax.legend()
ax.grid(True)

# %%
for i, f in enumerate(FOLDS):
    class_counts = np.zeros(3)
    fold_mask = delta_pairs_df['index1'].isin(incountry_folds[f]['test']).values
    for j in [0, 1, 2]:
        class_counts[j] = np.sum(labels_diffs_classes[fold_mask] == j)
    normalized_class_counts = class_counts / class_counts.sum()
    print(f, np.argmax(normalized_class_counts), np.max(normalized_class_counts))
# Out:
# A 2 0.3850746268656716
# B 2 0.4
# C 2 0.35777126099706746
# D 1 0.3687315634218289
# E 2 0.38738738738738737

# %% [markdown]
# ## Histogram Baseline

# %%
def run_incountry(features, labels, incountry_group_labels):
    num_examples = len(features)
    test_preds = np.zeros(num_examples, dtype=np.float32)

    do_plot = True
    for i, fold in enumerate(FOLDS):
        print('Fold:', fold)
        test_mask = (incountry_group_labels == i)
        test_preds[test_mask] = train_linear_logo(
            features=features,
            labels=labels,
            group_labels=incountry_group_labels,
            cv_groups=[x for x in range(5) if x != i],
            test_groups=[i],
            plot=do_plot,
            group_names=FOLDS)
        do_plot = False
    return test_preds

# %%
test_preds_dfs = []
for bands_name, band_indices in BANDS_DICT.items():
    print('===', bands_name, '===')
    test_preds = run_incountry(
        features=normalized_hists_diffs[:, band_indices, :].reshape(npairs*2, -1),
        labels=labels_diffs_aug,
        incountry_group_labels=incountry_group_labels_aug)
    test_preds_df = pd.DataFrame(data={
        'preds': test_preds,
        'labels': labels_diffs_aug,
        'fold': np.asarray(FOLDS)[incountry_group_labels_aug],
        'country': np.asarray(LSMS_COUNTRIES)[country_labels_aug],
        'bands': bands_name
    })
    test_preds_dfs.append(test_preds_df)
# Out:
# === rgb ===
# Fold: A
# best val mse: 0.127, best alpha: 8192.0, test mse: 0.137
# Fold: B
# best val mse: 0.133, best alpha: 1024.0, test mse: 0.119
# Fold: C
# best val mse: 0.130, best alpha: 8192.0, test mse: 0.122
# Fold: D
# best val mse: 0.130, best alpha: 1024.0, test mse: 0.121
# Fold: E
# best val mse: 0.124, best alpha: 1024.0, test mse: 0.143
# === rgbnl ===
# Fold: A
# best val mse: 0.126, best alpha: 8192.0, test mse: 0.134
# Fold: B
# best val mse: 0.124, best alpha: 1024.0, test mse: 0.120
# Fold: C
# best val mse: 0.127, best alpha: 1024.0, test mse: 0.112
# Fold: D
# best val mse: 0.124, best alpha: 1024.0, test mse: 0.119
# Fold: E
# best val mse: 0.124, best alpha: 1024.0, test mse: 0.135
# === ms ===
# Fold: A
# best val mse: 0.125, best alpha: 8192.0, test mse: 0.132
# Fold: B
# best val mse: 0.130, best alpha: 8192.0, test mse: 0.113
# Fold: C
# best val mse: 0.126, best alpha: 8192.0, test mse: 0.123
# Fold: D
# best val mse: 0.127, best alpha: 8192.0, test mse: 0.118
# Fold: E
# best val mse: 0.123, best alpha: 8192.0, test mse: 0.141
# === msnl ===
# Fold: A
# best val mse: 0.124, best alpha: 8192.0, test mse: 0.130
# Fold: B
# best val mse: 0.128, best alpha: 8192.0, test mse: 0.113
# Fold: C
# best val mse: 0.125, best alpha: 8192.0, test mse: 0.120
# Fold: D
# best val mse: 0.124, best alpha: 1024.0, test mse: 0.118
# Fold: E
# best val mse: 0.123, best alpha: 8192.0, test mse: 0.137
# === nl ===
# Fold: A
# best val mse: 0.130, best alpha: 1024.0, test mse: 0.145
# Fold: B
# best val mse: 0.136, best alpha: 1024.0, test mse: 0.121
# Fold: C
# best val mse: 0.135, best alpha: 1024.0, test mse: 0.124
# Fold: D
# best val mse: 0.136, best alpha: 1024.0, test mse: 0.125
# Fold: E
# best val mse: 0.132, best alpha: 17179869184.0, test mse: 0.162

# %%
for bands_name, features in [('nlmean', nls_mean_diffs_aug), ('nlcenter', nls_center_diffs_aug)]:
    print('===', bands_name, '===')
    test_preds = run_incountry(
        features=nls_center_diffs_aug.reshape(-1, 1),
        labels=labels_diffs_aug,
        incountry_group_labels=incountry_group_labels_aug)
    test_preds_df = pd.DataFrame(data={
        'preds': test_preds,
        'labels': labels_diffs_aug,
        'fold': np.asarray(FOLDS)[incountry_group_labels_aug],
        'country': np.asarray(LSMS_COUNTRIES)[country_labels_aug],
        'bands': bands_name
    })
    test_preds_dfs.append(test_preds_df)
# Out:
# === nlmean ===
# Fold: A
# best val mse: 0.134, best alpha: 17179869184.0, test mse: 0.152
# Fold: B
# best val mse: 0.142, best alpha: 17179869184.0, test mse: 0.123
# Fold: C
# best val mse: 0.141, best alpha: 17179869184.0, test mse: 0.126
# Fold: D
# best val mse: 0.140, best alpha: 128.0, test mse: 0.152
# Fold: E
# best val mse: 0.132, best alpha: 17179869184.0, test mse: 0.162
# === nlcenter ===
# Fold: A
# best val mse: 0.134, best alpha: 17179869184.0, test mse: 0.152
# Fold: B
# best val mse: 0.142, best alpha: 17179869184.0, test mse: 0.123
# Fold: C
# best val mse: 0.141, best alpha: 17179869184.0, test mse: 0.126
# Fold: D
# best val mse: 0.140, best alpha: 128.0, test mse: 0.152
# Fold: E
# best val mse: 0.132, best alpha: 17179869184.0, test mse: 0.162

# %%
test_preds_df = pd.concat(test_preds_dfs).reset_index()
with pd.option_context('display.max_rows', 4):
    display(test_preds_df)
# Out:
#        index         preds    labels fold   country     bands
# 0          0 -5.717006e-03  0.127949    C  ethiopia       rgb
# 1          1 -4.611732e-02  0.184329    E  ethiopia       rgb
# ...      ...           ...       ...  ...       ...       ...
# 24190   3454 -3.001378e-09  0.321629    B    uganda  nlcenter
# 24191   3455 -3.001514e-09 -0.023931    B    uganda  nlcenter
#
# [24192 rows x 6 columns]

# %%
results_df = test_preds_df.groupby('bands').apply(evaluate_df)
colordisplay(results_df)
# Out:
# <style  type="text/css" >
#     #T_d3949d96_6649_11e9_9040_1d70fc435d90row0_col0 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row0_col1 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row0_col2 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row0_col3 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row1_col1 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row1_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row2_col0 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row2_col1 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row2_col2 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row2_col3 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row3_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row3_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row4_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row5_col0 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row5_col1 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row5_col2 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row5_col3 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row6_col0 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row6_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row6_col2 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_d3949d96_6649_11e9_9040_1d70fc435d90row6_col3 {
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }</style><table id="T_d3949d96_6649_11e9_9040_1d70fc435d90" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >bands</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d3949d96_6649_11e9_9040_1d70fc435d90level0_row0" class="row_heading level0 row0" >ms</th>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row0_col0" class="data row0 col0" >0.0921446</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row0_col1" class="data row0 col1" >-10.0494</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row0_col2" class="data row0 col2" >0.125057</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row0_col3" class="data row0 col3" >0.304645</td>
#             </tr>
#             <tr>
#                         <th id="T_d3949d96_6649_11e9_9040_1d70fc435d90level0_row1" class="row_heading level0 row1" >msnl</th>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row1_col0" class="data row1 col0" >0.105157</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row1_col1" class="data row1 col1" >-6.8814</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row1_col2" class="data row1 col2" >0.123248</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row1_col3" class="data row1 col3" >0.321032</td>
#             </tr>
#             <tr>
#                         <th id="T_d3949d96_6649_11e9_9040_1d70fc435d90level0_row2" class="row_heading level0 row2" >nl</th>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row2_col0" class="data row2 col0" >0.0232592</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row2_col1" class="data row2 col1" >-18.9756</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row2_col2" class="data row2 col2" >0.135162</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row2_col3" class="data row2 col3" >0.189189</td>
#             </tr>
#             <tr>
#                         <th id="T_d3949d96_6649_11e9_9040_1d70fc435d90level0_row3" class="row_heading level0 row3" >nlcenter</th>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row3_col0" class="data row3 col0" >5.1503e-06</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row3_col1" class="data row3 col1" >-30.963</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row3_col2" class="data row3 col2" >0.14227</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row3_col3" class="data row3 col3" >-0.0567465</td>
#             </tr>
#             <tr>
#                         <th id="T_d3949d96_6649_11e9_9040_1d70fc435d90level0_row4" class="row_heading level0 row4" >nlmean</th>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row4_col0" class="data row4 col0" >5.1503e-06</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row4_col1" class="data row4 col1" >-30.963</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row4_col2" class="data row4 col2" >0.14227</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row4_col3" class="data row4 col3" >-0.0567465</td>
#             </tr>
#             <tr>
#                         <th id="T_d3949d96_6649_11e9_9040_1d70fc435d90level0_row5" class="row_heading level0 row5" >rgb</th>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row5_col0" class="data row5 col0" >0.0724588</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row5_col1" class="data row5 col1" >-7.8199</td>
#                         <td id="T_d3949d96_6649_11e9_9040_1d70fc435d90row5_col2" class="data row5 col2" >0.128155</td>

# %%
results_cfb_df = test_preds_df.groupby(['country', 'fold', 'bands']).apply(evaluate_df)
colordisplay(results_cfb_df)
# Out:
# <style  type="text/css" >
#     #T_d5736d7c_6649_11e9_9040_1d70fc435d90row0_col0 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row0_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row0_col3 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row1_col0 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row1_col2 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row1_col3 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row2_col0 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row2_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row2_col2 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row2_col3 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row3_col0 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row3_col1 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row3_col2 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row3_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row4_col0 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row4_col1 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row4_col2 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row5_col0 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row5_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row5_col2 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row5_col3 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row6_col0 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row6_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row6_col2 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row6_col3 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row7_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row7_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row7_col2 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row7_col3 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row8_col0 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row8_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row8_col2 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row8_col3 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row9_col0 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row9_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row9_col2 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row9_col3 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row10_col0 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row10_col1 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row10_col2 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row10_col3 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row11_col0 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row11_col1 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row11_col2 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row11_col3 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row12_col0 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row12_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row12_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row12_col3 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row13_col0 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row13_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row13_col2 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row13_col3 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row14_col0 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row14_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row14_col2 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_d5736d7c_6649_11e9_9040_1d70fc435d90row14_col3 {
#             background-color:  #ead5c9;

# %%
g = sns.lmplot(data=test_preds_df, row='country', col='bands', x='labels', y='preds',
               height=3, truncate=True, scatter_kws={'s': 2})
g = g.set(ylim=(-2, 2), xlim=(-2, 2), aspect='equal')

# %%
g = sns.lmplot(data=test_preds_df, row='country', col='bands', hue='fold', x='labels', y='preds',
               height=3, truncate=True, scatter_kws={'s': 2})
g = g.set(ylim=(-2, 2), xlim=(-2, 2), aspect='equal')

# %%
results_bycountry_df = test_preds_df.groupby(['country', 'bands']).apply(evaluate_df)
colordisplay(results_bycountry_df)
# Out:
# <style  type="text/css" >
#     #T_0855cfbe_664a_11e9_9040_1d70fc435d90row0_col0 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row0_col2 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row0_col3 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row1_col0 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row1_col2 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row1_col3 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row2_col0 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row2_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row2_col2 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row2_col3 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row3_col0 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row3_col1 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row3_col2 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row3_col3 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row4_col0 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row4_col1 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row4_col2 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row4_col3 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row5_col0 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row5_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row5_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row5_col3 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row6_col0 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row6_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row6_col2 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row6_col3 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row7_col0 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row7_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row7_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row7_col3 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row8_col0 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row8_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row8_col2 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row8_col3 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row9_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row9_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row9_col2 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row9_col3 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row10_col0 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row10_col1 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row10_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row10_col3 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row11_col0 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row11_col1 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row11_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row11_col3 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row12_col0 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row12_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row12_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row12_col3 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row13_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row13_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row13_col2 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row13_col3 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row14_col0 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row14_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row14_col2 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_0855cfbe_664a_11e9_9040_1d70fc435d90row14_col3 {
#             background-color:  #c0282f;

# %%
results_byfold_df = test_preds_df.groupby(['fold', 'bands']).apply(evaluate_df)
colordisplay(results_byfold_df)
# Out:
# <style  type="text/css" >
#     #T_08ade4a6_664a_11e9_9040_1d70fc435d90row0_col0 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row0_col2 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row0_col3 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row1_col0 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row1_col2 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row1_col3 {
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row2_col0 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row2_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row2_col2 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row2_col3 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row3_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row3_col1 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row3_col2 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row3_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row4_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row4_col1 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row4_col2 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row4_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row5_col0 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row5_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row5_col2 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row5_col3 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row6_col0 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row6_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row6_col2 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row6_col3 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row7_col0 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row7_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row7_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row7_col3 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row8_col0 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row8_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row8_col2 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row8_col3 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row9_col0 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row9_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row9_col2 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row9_col3 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row10_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row10_col1 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row10_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row10_col3 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row11_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row11_col1 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row11_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row11_col3 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row12_col0 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row12_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row12_col2 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row12_col3 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row13_col0 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row13_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row13_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row13_col3 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row14_col0 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row14_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row14_col2 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_08ade4a6_664a_11e9_9040_1d70fc435d90row14_col3 {
#             background-color:  #f5c0a7;

# %%
ax = results_byfold_df['r2'].unstack('bands').T.plot(kind='bar', grid=True, width=0.7)
ax.set_ylabel('r^2')
ax.set_title('Baseline test r^2')
plt.show()

# %%
r2s_df = results_byfold_df['r2'].unstack('bands').agg([np.median, np.mean, np.std]).T
colordisplay(r2s_df)

ax = r2s_df.plot(kind='bar', y='mean', yerr='std', grid=True)
ax.set_ylabel('r^2')
ax.set_title('Baseline test r^2 (err. +/- 1 std)')
plt.show()
# Out:
# <style  type="text/css" >
#     #T_08f7f938_664a_11e9_9040_1d70fc435d90row0_col0 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row0_col1 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row0_col2 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row1_col0 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row1_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row2_col0 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row2_col1 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row2_col2 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row5_col0 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row5_col1 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row5_col2 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row6_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row6_col1 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_08f7f938_664a_11e9_9040_1d70fc435d90row6_col2 {
#             background-color:  #f39778;
#             color:  #000000;
#         }</style><table id="T_08f7f938_664a_11e9_9040_1d70fc435d90" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >median</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08f7f938_664a_11e9_9040_1d70fc435d90level0_row0" class="row_heading level0 row0" >ms</th>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row0_col0" class="data row0 col0" >0.0812617</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row0_col1" class="data row0 col1" >0.0990045</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row0_col2" class="data row0 col2" >0.0489226</td>
#             </tr>
#             <tr>
#                         <th id="T_08f7f938_664a_11e9_9040_1d70fc435d90level0_row1" class="row_heading level0 row1" >msnl</th>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row1_col0" class="data row1 col0" >0.105124</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row1_col1" class="data row1 col1" >0.117159</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row1_col2" class="data row1 col2" >0.0537254</td>
#             </tr>
#             <tr>
#                         <th id="T_08f7f938_664a_11e9_9040_1d70fc435d90level0_row2" class="row_heading level0 row2" >nl</th>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row2_col0" class="data row2 col0" >0.022885</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row2_col1" class="data row2 col1" >0.027277</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row2_col2" class="data row2 col2" >0.0120313</td>
#             </tr>
#             <tr>
#                         <th id="T_08f7f938_664a_11e9_9040_1d70fc435d90level0_row3" class="row_heading level0 row3" >nlcenter</th>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row3_col0" class="data row3 col0" >0.00158914</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row3_col1" class="data row3 col1" >0.0047518</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row3_col2" class="data row3 col2" >0.00851684</td>
#             </tr>
#             <tr>
#                         <th id="T_08f7f938_664a_11e9_9040_1d70fc435d90level0_row4" class="row_heading level0 row4" >nlmean</th>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row4_col0" class="data row4 col0" >0.00158914</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row4_col1" class="data row4 col1" >0.0047518</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row4_col2" class="data row4 col2" >0.00851684</td>
#             </tr>
#             <tr>
#                         <th id="T_08f7f938_664a_11e9_9040_1d70fc435d90level0_row5" class="row_heading level0 row5" >rgb</th>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row5_col0" class="data row5 col0" >0.0704111</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row5_col1" class="data row5 col1" >0.0807278</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row5_col2" class="data row5 col2" >0.0388524</td>
#             </tr>
#             <tr>
#                         <th id="T_08f7f938_664a_11e9_9040_1d70fc435d90level0_row6" class="row_heading level0 row6" >rgbnl</th>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row6_col0" class="data row6 col0" >0.113154</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row6_col1" class="data row6 col1" >0.115556</td>
#                         <td id="T_08f7f938_664a_11e9_9040_1d70fc435d90row6_col2" class="data row6 col2" >0.0427073</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Single Model

# %%
mask = {}
mask['test'] = (incountry_group_labels_aug == 0)
mask['val'] = (incountry_group_labels_aug == 4)
mask['train'] = ~(mask['test'] | mask['val'])

# %%
preds = {split: [] for split in SPLITS}
results = train_linear_model(
    normalized_hists_diffs[mask['train']].reshape(np.sum(mask['train']), -1), labels_diffs_aug[mask['train']],
    normalized_hists_diffs[mask['val']].reshape(np.sum(mask['val']), -1), labels_diffs_aug[mask['val']])
best_model, preds['train'], preds['val'] = results

# %%
preds['test'] = best_model.predict(normalized_hists_diffs[mask['test']].reshape(np.sum(mask['test']), -1))

for split in SPLITS:
    _ = evaluate(labels=labels_diffs_aug[mask[split]], preds=preds[split],
                 do_print=True, title=split)

cumulative_r2s = {}
labels_diffs_aug_sorted = {}
for split in SPLITS:
    cumulative_r2s[split], labels_diffs_aug_sorted[split] = sorted_scores(
        preds=preds[split], labels=labels_diffs_aug[mask[split]], metric='r2', sort='increasing')

plot_label_vs_score(
    scores_list=[cumulative_r2s[split] for split in SPLITS],
    labels_list=[labels_diffs_aug_sorted[split] for split in SPLITS],
    legends=SPLITS,
    metric='r2',
    sort='increasing')
# Out:
# train	- r^2: 0.328, R^2: 0.286, mse: 0.089, rank: 0.513
# val	- r^2: 0.134, R^2: 0.130, mse: 0.141, rank: 0.389
# test	- r^2: 0.098, R^2: 0.096, mse: 0.137, rank: 0.290
# /atlas/u/chrisyeh/miniconda3/envs/py37/lib/python3.7/site-packages/scipy/stats/stats.py:3038: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# /atlas/u/chrisyeh/miniconda3/envs/py37/lib/python3.7/site-packages/scipy/stats/stats.py:3049: RuntimeWarning: invalid value encountered in double_scalars
#   0.5*df, 0.5, np.fmin(np.asarray(df / (df + t_squared)), 1.0)
