# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports-+-Constants" data-toc-modified-id="Imports-+-Constants-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports + Constants</a></span></li><li><span><a href="#Load-histograms-(or-create-if-needed)" data-toc-modified-id="Load-histograms-(or-create-if-needed)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load histograms (or create if needed)</a></span><ul class="toc-item"><li><span><a href="#Split-NL-band" data-toc-modified-id="Split-NL-band-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Split NL band</a></span></li><li><span><a href="#Plot-histograms" data-toc-modified-id="Plot-histograms-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Plot histograms</a></span></li><li><span><a href="#Normalize-histograms" data-toc-modified-id="Normalize-histograms-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Normalize histograms</a></span></li></ul></li><li><span><a href="#Load-data" data-toc-modified-id="Load-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#OOC-Predictions" data-toc-modified-id="OOC-Predictions-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>OOC Predictions</a></span><ul class="toc-item"><li><span><a href="#rgb" data-toc-modified-id="rgb-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>rgb</a></span></li><li><span><a href="#ms" data-toc-modified-id="ms-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>ms</a></span></li><li><span><a href="#nl" data-toc-modified-id="nl-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>nl</a></span></li><li><span><a href="#msnl" data-toc-modified-id="msnl-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>msnl</a></span></li></ul></li><li><span><a href="#Incountry-Predictions" data-toc-modified-id="Incountry-Predictions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Incountry Predictions</a></span><ul class="toc-item"><li><span><a href="#Predict-country-mean" data-toc-modified-id="Predict-country-mean-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Predict country mean</a></span></li><li><span><a href="#Histogram-model" data-toc-modified-id="Histogram-model-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Histogram model</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Imports + Constants

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from collections import defaultdict
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pickle
import pandas as pd
import seaborn as sns

sys.path.append('/atlas/u/chrisyeh/africa_poverty/')
from batchers import batcher, dataset_constants
from histograms import get_per_image_histograms, split_nl_hist
from models.linear_model import train_linear_logo
from utils.analysis import evaluate
from utils.general import load_npz

# %%
SPLITS = ['train', 'val', 'test']
FOLDS = ['A', 'B', 'C', 'D', 'E']

DATASET_NAME = 'LSMS'
LABEL_NAME = 'wealthpooled'

# %% [markdown]
# # Load histograms (or create if needed)

# %%
# BAND_BIN_EDGES = [-10^5, -5.0, -4.9, -4.8, ..., 4.8, 4.9, 5.0, 10^5]
# BAND_BIN_CENTERS = [-5.05, -4.95, -4.85, ..., 4.85, 4.95, 5.05]
BAND_BIN_EDGES = np.concatenate([
    [-1e5],
    np.arange(-5.0, 5.1, 0.1),
    [1e5]
])
BAND_BIN_CENTERS = np.arange(-5.05, 5.15, 0.1)

# LABEL_BIN_EDGES = [-2.0, -1.9, ..., 2.8, 2.9]
# LABEL_BIN_CENTERS = [-1.95, -1.85, ..., 2.75, 2.85]
LABEL_BIN_EDGES = np.arange(-2.0, 3.0, 0.1)
LABEL_BIN_CENTERS = np.arange(-1.95, 2.95, 0.1)

# band name => color for plotting
BAND_COLORS = {
    'BLUE'  : 'blue',
    'GREEN' : 'green',
    'RED'   : 'red',
    'SWIR1' : 'purple',
    'SWIR2' : 'brown',
    'TEMP1' : 'orange',
    'NIR'   : 'pink',
    'NIGHTLIGHTS': 'black',
    'DMSP'  : 'black',
    'VIIRS' : 'gray',
}
BAND_ORDER = ['BLUE', 'GREEN', 'RED', 'SWIR1', 'TEMP1', 'SWIR2', 'NIR', 'NIGHTLIGHTS']
BAND_ORDER_NLSPLIT = ['BLUE', 'GREEN', 'RED', 'SWIR1', 'TEMP1', 'SWIR2', 'NIR', 'DMSP', 'VIIRS']

BANDS_DICT = {
    'rgb': [0, 1, 2],
    'rgbnl': [0, 1, 2, 7, 8],
    'ms': [0, 1, 2, 3, 4, 5, 6],
    'msnl': [0, 1, 2, 3, 4, 5, 6, 7, 8],
    'nl': [7, 8],
}

# %%
def get_batcher(tfrecord_files):
    return batcher.Batcher(
        tfrecord_files=tfrecord_files,
        dataset=DATASET_NAME,
        batch_size=128,
        ls_bands='ms',
        nl_band='merge',
        label_name=LABEL_NAME,
        shuffle=False,
        augment=False,
        negatives='zero',
        normalize=True)

# %%
file_path = '/atlas/u/chrisyeh/africa_poverty/data/image_hists_lsms.npz'

if not os.path.exists(file_path):
    tfrecord_paths = batcher.get_lsms_tfrecord_paths(dataset_constants.SURVEY_NAMES['LSMS'])
    init_iter, batch_op = get_batcher(tfrecord_paths).get_batch()
    results = get_per_image_histograms(init_iter, batch_op, band_bin_edges=BAND_BIN_EDGES)
    print('Saving image histograms to', file_path)
    np.savez_compressed(file_path, **results)

# %%
result = load_npz(file_path)
image_hists = result['image_hists']
labels = result['labels']
locs = result['locs']
years = result['years']
nls_center = result['nls_center']
nls_mean = result['nls_mean']
# Out:
# image_hists: dtype=int64, shape=(3020, 8, 102)
# labels: dtype=float32, shape=(3020,)
# locs: dtype=float32, shape=(3020, 2)
# years: dtype=int32, shape=(3020,)
# nls_center: dtype=float32, shape=(3020,)
# nls_mean: dtype=float32, shape=(3020,)

# %% [markdown]
# ## Split NL band

# %%
# split NL band
image_hists = split_nl_hist(image_hists, years)

# %% [markdown]
# ## Plot histograms

# %%
def plot_band_hists(band_hists, band_order, bin_centers, xlabel, ylabel, title, yscale='linear'):
    '''
    Args
    - band_hists: np.array, shape [C, nbins]
      - assumes DMSP and VIIRS each have their own band
    - band_order: list of str
    - bin_centers: np.array, shape [nbins]
    - xlabel, ylabel, title: str
    - yscale: str, one of ['linear', 'log']
    '''
    fig, ax = plt.subplots(1, 1, figsize=[10, 4])
    nbands = band_hists.shape[0]
    for b in range(nbands):
        band_name = band_order[b]
        ax.plot(bin_centers, band_hists[b], label=band_name, color=BAND_COLORS[band_name])
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_yscale(yscale)
    ax.set_title(title)
    ax.grid(True)
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

def plot_label_hist(labels, bin_centers, title):
    '''
    Args
    - labels: np.array, shape [num_images]
    - bin_centers: np.array, shape [num_label_bins]
    - title: str
    '''
    fig, ax = plt.subplots(1, 1, figsize=[10, 4])
    ax.hist(labels, bins=LABEL_BIN_EDGES)
    ax.set_xlabel('label')
    ax.set_ylabel('count')
    ax.set_title(title)
    ax.grid(True)
    plt.show()

# %%
band_hists = np.sum(image_hists, axis=0, dtype=np.int64)  # shape [C, nbins]
plot_band_hists(band_hists, BAND_ORDER_NLSPLIT, BAND_BIN_CENTERS,
    xlabel='normalized pixel value', ylabel='count', title='pixel distributions - all', yscale='log')
plot_label_hist(labels, LABEL_BIN_CENTERS, title='label distributions - all')

# %% [markdown]
# ## Normalize histograms

# %%
image_hists_mean = np.mean(image_hists, axis=0, dtype=np.float64)
image_hists_std = np.std(image_hists, axis=0, dtype=np.float64)
normalized_image_hists = (image_hists - image_hists_mean) / (image_hists_std + 1e-6)
print(normalized_image_hists.shape)
# Out:
# (3020, 9, 102)

# %% [markdown]
# # Load data

# %%
# file that Anne sent to me
LSMS_CSV_PATH = '/atlas/u/chrisyeh/africa_poverty/data/lsms_labels_agg.csv'
lsms_df = pd.read_csv(LSMS_CSV_PATH, float_precision='high')
lsms_df['lat'] = lsms_df['lat'].astype(np.float32)
lsms_df['lon'] = lsms_df['lon'].astype(np.float32)

CID_TO_C = {
    'et': 'ethiopia',
    'mw': 'malawi',
    'ng': 'nigeria',
    'tz': 'tanzania',
    'ug': 'uganda',
}

LSMS_COUNTRIES = ['ethiopia', 'malawi', 'nigeria', 'tanzania', 'uganda']

# %%
# create mapping: loc => country
loc_to_country = (lsms_df
    .groupby(['lat', 'lon'])
    .apply(lambda df: df['country'].iloc[0])
    .map(CID_TO_C)
    .to_dict())

country_indices = defaultdict(list)  # country => np.array of indices
country_labels = np.zeros(len(lsms_df), dtype=np.int32)  # np.array of country labels

for i, loc in enumerate(locs):
    country = loc_to_country[tuple(loc)]
    country_indices[country].append(i)

for i, country in enumerate(LSMS_COUNTRIES):
    country_indices[country] = np.asarray(country_indices[country])
    indices = country_indices[country]
    country_labels[indices] = i

# %% [markdown]
# # OOC Predictions

# %%
def run_ooc(country, band_indices):
    nbands = len(band_indices)
    nbins = len(BAND_BIN_CENTERS)
    test_group = LSMS_COUNTRIES.index(country)
    num_examples = len(normalized_image_hists)
    test_preds, coefs, intercept = train_linear_logo(
        features=normalized_image_hists[:, band_indices, :].reshape(num_examples, -1),
        labels=labels,
        group_labels=country_labels,
        cv_groups=[i for i in range(len(LSMS_COUNTRIES)) if test_group != i],
        test_groups=[test_group],
        plot=True, group_names=LSMS_COUNTRIES, return_weights=True)
    print('best intercept:', intercept)
    per_band_coefs = coefs.reshape(nbands, nbins)
    plot_band_hists(per_band_coefs, np.asarray(BAND_ORDER_NLSPLIT)[band_indices], BAND_BIN_CENTERS,
        xlabel='normalized pixel value', ylabel='weight', title='Ridge Regression Weights per Band', yscale='linear')
    return evaluate(test_preds, labels[country_indices[country]], do_print=True)

# %% [markdown]
# ## rgb

# %%
rgb_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
rgb_df.set_index('country', inplace=True)

for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    rgb_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['rgb'])
# Out:
# === ethiopia ===
# best val mse: 0.796, best alpha: 1024.0, test mse: 1.149
# best intercept: 0.27665382385248505
# r^2: 0.003, R^2: -12.699, mse: 1.149, rank: -0.099
# === malawi ===
# best val mse: 1.002, best alpha: 1024.0, test mse: 0.248
# best intercept: 0.05904070623287576
# r^2: 0.037, R^2: -3.736, mse: 0.248, rank: 0.170
# === nigeria ===
# best val mse: 0.591, best alpha: 17179869184.0, test mse: 1.870
# best intercept: -0.3135659352767565
# r^2: 0.000, R^2: -141996216512211.438, mse: 1.870, rank: 0.094
# === tanzania ===
# best val mse: 1.492, best alpha: 128.0, test mse: 0.617
# best intercept: 0.14841169455581218
# r^2: 0.218, R^2: -0.052, mse: 0.617, rank: 0.492
# === uganda ===
# best val mse: 1.190, best alpha: 1024.0, test mse: 0.522
# best intercept: 0.06002475131515637
# r^2: 0.009, R^2: -8.317, mse: 0.522, rank: 0.055

# %%
display(rgb_df.style.background_gradient(cmap='coolwarm'))
# Out:
# <style  type="text/css" >
#     #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow0_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow0_col2 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow1_col0 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow1_col3 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow2_col3 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow3_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow3_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow3_col2 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow4_col0 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow4_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow4_col2 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow4_col3 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }</style><table id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398elevel0_row0" class="row_heading level0 row0" >ethiopia</th>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow0_col0" class="data row0 col0" >0.00275165</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow0_col1" class="data row0 col1" >-12.6989</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow0_col2" class="data row0 col2" >1.14938</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow0_col3" class="data row0 col3" >-0.0985496</td>
#             </tr>
#             <tr>
#                         <th id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398elevel0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow1_col0" class="data row1 col0" >0.037049</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow1_col1" class="data row1 col1" >-3.73572</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow1_col2" class="data row1 col2" >0.247897</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow1_col3" class="data row1 col3" >0.169638</td>
#             </tr>
#             <tr>
#                         <th id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398elevel0_row2" class="row_heading level0 row2" >nigeria</th>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow2_col0" class="data row2 col0" >0.000291603</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow2_col1" class="data row2 col1" >-1.41996e+14</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow2_col2" class="data row2 col2" >1.86967</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow2_col3" class="data row2 col3" >0.0938802</td>
#             </tr>
#             <tr>
#                         <th id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398elevel0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow3_col0" class="data row3 col0" >0.217606</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow3_col1" class="data row3 col1" >-0.0522983</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow3_col2" class="data row3 col2" >0.616936</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow3_col3" class="data row3 col3" >0.492312</td>
#             </tr>
#             <tr>
#                         <th id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398elevel0_row4" class="row_heading level0 row4" >uganda</th>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow4_col0" class="data row4 col0" >0.00912378</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow4_col1" class="data row4 col1" >-8.31685</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow4_col2" class="data row4 col2" >0.521783</td>
#                         <td id="T_27d4ed06_5bd3_11e9_978e_df8c07b9398erow4_col3" class="data row4 col3" >0.0551003</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## ms

# %%
ms_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
ms_df.set_index('country', inplace=True)

for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    ms_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['ms'])
# Out:
# === ethiopia ===
# best val mse: 0.834, best alpha: 8192.0, test mse: 1.435
# best intercept: 0.307940844271197
# r^2: 0.000, R^2: -16.165, mse: 1.435, rank: -0.095
# === malawi ===
# best val mse: 1.156, best alpha: 8192.0, test mse: 0.183
# best intercept: 0.06870725539382323
# r^2: 0.121, R^2: -4.622, mse: 0.183, rank: 0.357
# === nigeria ===
# best val mse: 0.499, best alpha: 1024.0, test mse: 1.803
# best intercept: -0.30521542536561996
# r^2: 0.092, R^2: -11.446, mse: 1.803, rank: 0.312
# === tanzania ===
# best val mse: 1.573, best alpha: 17179869184.0, test mse: 0.401
# best intercept: 0.13493993774708507
# r^2: 0.082, R^2: -333709375606.974, mse: 0.401, rank: 0.342
# === uganda ===
# best val mse: 1.300, best alpha: 1024.0, test mse: 0.537
# best intercept: 0.039608801830527895
# r^2: 0.046, R^2: -4.044, mse: 0.537, rank: 0.149

# %%
display(ms_df.style.background_gradient(cmap='coolwarm'))
# Out:
# <style  type="text/css" >
#     #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow0_col2 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow1_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow2_col0 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow2_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow2_col3 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow3_col0 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow3_col2 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow3_col3 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow4_col0 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow4_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow4_col2 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_30c20c78_5bd3_11e9_978e_df8c07b9398erow4_col3 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }</style><table id="T_30c20c78_5bd3_11e9_978e_df8c07b9398e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_30c20c78_5bd3_11e9_978e_df8c07b9398elevel0_row0" class="row_heading level0 row0" >ethiopia</th>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow0_col0" class="data row0 col0" >0.000476464</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow0_col1" class="data row0 col1" >-16.1652</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow0_col2" class="data row0 col2" >1.43454</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow0_col3" class="data row0 col3" >-0.0946592</td>
#             </tr>
#             <tr>
#                         <th id="T_30c20c78_5bd3_11e9_978e_df8c07b9398elevel0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow1_col0" class="data row1 col0" >0.121195</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow1_col1" class="data row1 col1" >-4.62202</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow1_col2" class="data row1 col2" >0.1835</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow1_col3" class="data row1 col3" >0.356824</td>
#             </tr>
#             <tr>
#                         <th id="T_30c20c78_5bd3_11e9_978e_df8c07b9398elevel0_row2" class="row_heading level0 row2" >nigeria</th>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow2_col0" class="data row2 col0" >0.0924692</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow2_col1" class="data row2 col1" >-11.4456</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow2_col2" class="data row2 col2" >1.80254</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow2_col3" class="data row2 col3" >0.312422</td>
#             </tr>
#             <tr>
#                         <th id="T_30c20c78_5bd3_11e9_978e_df8c07b9398elevel0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow3_col0" class="data row3 col0" >0.0817442</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow3_col1" class="data row3 col1" >-3.33709e+11</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow3_col2" class="data row3 col2" >0.400714</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow3_col3" class="data row3 col3" >0.342041</td>
#             </tr>
#             <tr>
#                         <th id="T_30c20c78_5bd3_11e9_978e_df8c07b9398elevel0_row4" class="row_heading level0 row4" >uganda</th>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow4_col0" class="data row4 col0" >0.0460507</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow4_col1" class="data row4 col1" >-4.0438</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow4_col2" class="data row4 col2" >0.536555</td>
#                         <td id="T_30c20c78_5bd3_11e9_978e_df8c07b9398erow4_col3" class="data row4 col3" >0.149028</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## nl

# %%
nl_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
nl_df.set_index('country', inplace=True)

for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    nl_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['nl'])
# Out:
# === ethiopia ===
# best val mse: 0.755, best alpha: 1024.0, test mse: 0.939
# best intercept: 0.26349741566925267
# r^2: 0.044, R^2: -45.934, mse: 0.939, rank: 0.242
# === malawi ===
# best val mse: 0.834, best alpha: 128.0, test mse: 0.335
# best intercept: 0.10007132704437023
# r^2: 0.599, R^2: 0.054, mse: 0.335, rank: 0.647
# === nigeria ===
# best val mse: 0.332, best alpha: 128.0, test mse: 1.381
# best intercept: -0.2544513671378457
# r^2: 0.280, R^2: -3.690, mse: 1.381, rank: 0.481
# === tanzania ===
# best val mse: 1.053, best alpha: 128.0, test mse: 0.355
# best intercept: 0.154740211087065
# r^2: 0.489, R^2: 0.124, mse: 0.355, rank: 0.595
# === uganda ===
# best val mse: 1.017, best alpha: 128.0, test mse: 0.293
# best intercept: 0.058192194618842466
# r^2: 0.454, R^2: 0.211, mse: 0.293, rank: 0.598

# %%
display(nl_df.style.background_gradient(cmap='coolwarm'))
# Out:
# <style  type="text/css" >
#     #T_346942f6_5bd3_11e9_978e_df8c07b9398erow0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow0_col2 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow1_col2 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow1_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow2_col0 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow2_col1 {
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow2_col3 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow3_col0 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow3_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow3_col2 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow3_col3 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow4_col0 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow4_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_346942f6_5bd3_11e9_978e_df8c07b9398erow4_col3 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }</style><table id="T_346942f6_5bd3_11e9_978e_df8c07b9398e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_346942f6_5bd3_11e9_978e_df8c07b9398elevel0_row0" class="row_heading level0 row0" >ethiopia</th>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow0_col0" class="data row0 col0" >0.0441678</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow0_col1" class="data row0 col1" >-45.9336</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow0_col2" class="data row0 col2" >0.939187</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow0_col3" class="data row0 col3" >0.241722</td>
#             </tr>
#             <tr>
#                         <th id="T_346942f6_5bd3_11e9_978e_df8c07b9398elevel0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow1_col0" class="data row1 col0" >0.599337</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow1_col1" class="data row1 col1" >0.053813</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow1_col2" class="data row1 col2" >0.335454</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow1_col3" class="data row1 col3" >0.647462</td>
#             </tr>
#             <tr>
#                         <th id="T_346942f6_5bd3_11e9_978e_df8c07b9398elevel0_row2" class="row_heading level0 row2" >nigeria</th>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow2_col0" class="data row2 col0" >0.279512</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow2_col1" class="data row2 col1" >-3.68988</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow2_col2" class="data row2 col2" >1.38069</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow2_col3" class="data row2 col3" >0.481245</td>
#             </tr>
#             <tr>
#                         <th id="T_346942f6_5bd3_11e9_978e_df8c07b9398elevel0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow3_col0" class="data row3 col0" >0.488784</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow3_col1" class="data row3 col1" >0.123997</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow3_col2" class="data row3 col2" >0.355392</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow3_col3" class="data row3 col3" >0.595131</td>
#             </tr>
#             <tr>
#                         <th id="T_346942f6_5bd3_11e9_978e_df8c07b9398elevel0_row4" class="row_heading level0 row4" >uganda</th>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow4_col0" class="data row4 col0" >0.454391</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow4_col1" class="data row4 col1" >0.210772</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow4_col2" class="data row4 col2" >0.293278</td>
#                         <td id="T_346942f6_5bd3_11e9_978e_df8c07b9398erow4_col3" class="data row4 col3" >0.597761</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## msnl

# %%
msnl_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
msnl_df.set_index('country', inplace=True)

for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    msnl_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['msnl'])
# Out:
# === ethiopia ===
# best val mse: 0.777, best alpha: 1024.0, test mse: 1.087
# best intercept: 0.2702712690306847
# r^2: 0.007, R^2: -8.950, mse: 1.087, rank: 0.033
# === malawi ===
# best val mse: 0.984, best alpha: 1024.0, test mse: 0.123
# best intercept: 0.0702068623841288
# r^2: 0.522, R^2: 0.472, mse: 0.123, rank: 0.647
# === nigeria ===
# best val mse: 0.312, best alpha: 1024.0, test mse: 1.627
# best intercept: -0.2965688455752193
# r^2: 0.315, R^2: -5.988, mse: 1.627, rank: 0.588
# === tanzania ===
# best val mse: 1.305, best alpha: 1024.0, test mse: 0.386
# best intercept: 0.1400720662680557
# r^2: 0.399, R^2: 0.159, mse: 0.386, rank: 0.566
# === uganda ===
# best val mse: 1.108, best alpha: 1024.0, test mse: 0.375
# best intercept: 0.043330898621760525
# r^2: 0.317, R^2: -0.502, mse: 0.375, rank: 0.369

# %%
display(msnl_df.style.background_gradient(cmap='coolwarm'))
# Out:
# <style  type="text/css" >
#     #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow0_col2 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow1_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow2_col0 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow2_col1 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow2_col3 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow3_col0 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow3_col1 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow3_col2 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow3_col3 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow4_col0 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow4_col1 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow4_col2 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_40ce3998_5bd3_11e9_978e_df8c07b9398erow4_col3 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }</style><table id="T_40ce3998_5bd3_11e9_978e_df8c07b9398e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40ce3998_5bd3_11e9_978e_df8c07b9398elevel0_row0" class="row_heading level0 row0" >ethiopia</th>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow0_col0" class="data row0 col0" >0.00669636</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow0_col1" class="data row0 col1" >-8.95016</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow0_col2" class="data row0 col2" >1.08659</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow0_col3" class="data row0 col3" >0.0326322</td>
#             </tr>
#             <tr>
#                         <th id="T_40ce3998_5bd3_11e9_978e_df8c07b9398elevel0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow1_col0" class="data row1 col0" >0.52154</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow1_col1" class="data row1 col1" >0.472225</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow1_col2" class="data row1 col2" >0.12288</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow1_col3" class="data row1 col3" >0.647481</td>
#             </tr>
#             <tr>
#                         <th id="T_40ce3998_5bd3_11e9_978e_df8c07b9398elevel0_row2" class="row_heading level0 row2" >nigeria</th>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow2_col0" class="data row2 col0" >0.315273</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow2_col1" class="data row2 col1" >-5.98818</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow2_col2" class="data row2 col2" >1.62681</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow2_col3" class="data row2 col3" >0.587517</td>
#             </tr>
#             <tr>
#                         <th id="T_40ce3998_5bd3_11e9_978e_df8c07b9398elevel0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow3_col0" class="data row3 col0" >0.398929</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow3_col1" class="data row3 col1" >0.158528</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow3_col2" class="data row3 col2" >0.386328</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow3_col3" class="data row3 col3" >0.566405</td>
#             </tr>
#             <tr>
#                         <th id="T_40ce3998_5bd3_11e9_978e_df8c07b9398elevel0_row4" class="row_heading level0 row4" >uganda</th>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow4_col0" class="data row4 col0" >0.316965</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow4_col1" class="data row4 col1" >-0.501745</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow4_col2" class="data row4 col2" >0.374977</td>
#                         <td id="T_40ce3998_5bd3_11e9_978e_df8c07b9398erow4_col3" class="data row4 col3" >0.368807</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Incountry Predictions

# %%
# load incountry folds
file_path = '/atlas/u/chrisyeh/africa_poverty/data/lsms_incountry_folds.pkl'
with open(file_path, 'rb') as f:
    incountry_folds = pickle.load(f)

# %%
num_examples = len(image_hists)
incountry_group_labels = np.zeros(num_examples, dtype=np.int32)
for i, f in enumerate(FOLDS):
    test_indices = incountry_folds[f]['test']
    incountry_group_labels[test_indices] = i

# %% [markdown]
# ## Predict country mean

# %%
mean_preds = np.zeros(num_examples)
for i, country in enumerate(LSMS_COUNTRIES):
    indices = np.where(country_labels == i)[0]
    mean_preds[indices] = np.mean(labels[indices])
r2, R2, mse, rank = evaluate(labels, mean_preds, do_print=True)
# Out:
# r^2: 0.551, R^2: 0.551, mse: 0.337, rank: 0.748

# %%
df = pd.DataFrame({
    'labels': labels,
    'preds': mean_preds,
    'country': np.asarray(LSMS_COUNTRIES)[country_labels],
})
fig, ax = plt.subplots(1, 1, figsize=[5, 5], constrained_layout=True)
m, b = np.polyfit(labels, mean_preds, 1)
ax.plot([-2.3, 2.3], [-2.3, 2.3], '-y')
sns.scatterplot(data=df, x='labels', y='preds', hue='country', ax=ax)
ax.plot(labels, m * labels + b, ':k', label=f'$r^2={r2:.3g}$')
ax.set_aspect('equal')
ax.legend()
ax.grid(True)

# %% [markdown]
# ## Histogram model

# %%
def run_incountry(features, labels, incountry_group_labels):
    num_examples = len(features)
    test_preds = np.zeros(num_examples, dtype=np.float32)

    do_plot = True
    for i, fold in enumerate(FOLDS):
        print('Fold:', fold)
        test_indices = incountry_folds[fold]['test']
        test_preds[test_indices] = train_linear_logo(
            features=features,
            labels=labels,
            group_labels=incountry_group_labels,
            cv_groups=[x for x in range(5) if x != i],
            test_groups=[i],
            plot=do_plot,
            group_names=FOLDS)
        do_plot = False
    return test_preds

# %%
test_preds = run_incountry(
    normalized_image_hists.reshape(num_examples, -1), labels, incountry_group_labels)
# Out:
# Fold: A
# best val mse: 0.348, best alpha: 1024.0, test mse: 0.373
# Fold: B
# best val mse: 0.359, best alpha: 1024.0, test mse: 0.348
# Fold: C
# best val mse: 0.355, best alpha: 1024.0, test mse: 0.353
# Fold: D
# best val mse: 0.364, best alpha: 1024.0, test mse: 0.319
# Fold: E
# best val mse: 0.356, best alpha: 1024.0, test mse: 0.340
# r^2: 0.538, R^2: 0.103, mse: 0.347, rank: 0.733

# %%
test_preds_df = pd.DataFrame(data={
    'preds': test_preds,
    'labels': labels,
    'country': np.asarray(LSMS_COUNTRIES)[country_labels],
    'year': years
})
with pd.option_context('display.max_rows', 4):
    display(test_preds_df)
# Out:
#          preds    labels   country  year
# 0    -0.744204 -1.232088  ethiopia  2011
# 1    -0.163558 -0.869557  ethiopia  2011
# ...        ...       ...       ...   ...
# 3018  1.015059  1.379230    uganda  2013
# 3019  1.070682  1.180093    uganda  2013
#
# [3020 rows x 4 columns]

# %%
def evaluate_df(df):
    '''
    Args
    - df: pd.DataFrame, contains columns ['preds', 'labels']

    Returns: pd.Series, index ['r2', 'R2', 'mse', 'rank']
    '''
    r2, R2, mse, rank = evaluate(df['preds'], df['labels'])
    return pd.Series({'r2': r2, 'R2': R2, 'mse': mse, 'rank': rank})

results_bycountry_df = test_preds_df.groupby('country').apply(evaluate_df)
results_bycountry_df.loc['all', :] = evaluate_df(test_preds_df)
display(results_bycountry_df.style.background_gradient(cmap='coolwarm'))
# Out:
# <style  type="text/css" >
#     #T_b309b852_5bd3_11e9_978e_df8c07b9398erow0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow0_col2 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow1_col0 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow1_col3 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow2_col0 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow2_col1 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow2_col3 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow3_col0 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow3_col1 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow3_col2 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow3_col3 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow4_col0 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow4_col1 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow4_col2 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow4_col3 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow5_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow5_col1 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow5_col2 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_b309b852_5bd3_11e9_978e_df8c07b9398erow5_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_b309b852_5bd3_11e9_978e_df8c07b9398e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b309b852_5bd3_11e9_978e_df8c07b9398elevel0_row0" class="row_heading level0 row0" >ethiopia</th>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow0_col0" class="data row0 col0" >0.022593</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow0_col1" class="data row0 col1" >-2.40588</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow0_col2" class="data row0 col2" >0.368855</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow0_col3" class="data row0 col3" >0.158077</td>
#             </tr>
#             <tr>
#                         <th id="T_b309b852_5bd3_11e9_978e_df8c07b9398elevel0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow1_col0" class="data row1 col0" >0.535267</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow1_col1" class="data row1 col1" >0.477263</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow1_col2" class="data row1 col2" >0.115779</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow1_col3" class="data row1 col3" >0.639102</td>
#             </tr>
#             <tr>
#                         <th id="T_b309b852_5bd3_11e9_978e_df8c07b9398elevel0_row2" class="row_heading level0 row2" >nigeria</th>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow2_col0" class="data row2 col0" >0.294455</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow2_col1" class="data row2 col1" >-0.5601</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow2_col2" class="data row2 col2" >0.46721</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow2_col3" class="data row2 col3" >0.561145</td>
#             </tr>
#             <tr>
#                         <th id="T_b309b852_5bd3_11e9_978e_df8c07b9398elevel0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow3_col0" class="data row3 col0" >0.446941</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow3_col1" class="data row3 col1" >0.292438</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow3_col2" class="data row3 col2" >0.263773</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow3_col3" class="data row3 col3" >0.585378</td>
#             </tr>
#             <tr>
#                         <th id="T_b309b852_5bd3_11e9_978e_df8c07b9398elevel0_row4" class="row_heading level0 row4" >uganda</th>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow4_col0" class="data row4 col0" >0.402968</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow4_col1" class="data row4 col1" >-0.487912</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow4_col2" class="data row4 col2" >0.295996</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow4_col3" class="data row4 col3" >0.486439</td>
#             </tr>
#             <tr>
#                         <th id="T_b309b852_5bd3_11e9_978e_df8c07b9398elevel0_row5" class="row_heading level0 row5" >overall</th>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow5_col0" class="data row5 col0" >0.537902</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow5_col1" class="data row5 col1" >0.10346</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow5_col2" class="data row5 col2" >0.346778</td>
#                         <td id="T_b309b852_5bd3_11e9_978e_df8c07b9398erow5_col3" class="data row5 col3" >0.732542</td>
#             </tr>
#     </tbody></table>

# %%
results_bycy_df = test_preds_df.groupby(['country', 'year']).apply(evaluate_df)
display(results_bycy_df.style.background_gradient(cmap='coolwarm'))
# Out:
# <style  type="text/css" >
#     #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow0_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow0_col1 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow0_col2 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow0_col3 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow1_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow1_col2 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow2_col0 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow2_col1 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow2_col2 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow2_col3 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow3_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow3_col1 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow4_col0 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow4_col1 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow4_col2 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow4_col3 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow5_col0 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow5_col1 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow5_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow5_col3 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow6_col0 {
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow6_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow6_col2 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow6_col3 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow7_col0 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow7_col1 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow7_col2 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow7_col3 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow8_col0 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow8_col1 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow8_col2 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow8_col3 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow9_col0 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow9_col1 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow9_col2 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow9_col3 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow10_col0 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow10_col1 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow10_col2 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow10_col3 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }</style><table id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398e" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="index_name level1" >year</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398elevel0_row0" class="row_heading level0 row0" rowspan=2>ethiopia</th>
#                         <th id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398elevel1_row0" class="row_heading level1 row0" >2011</th>
#                         <td id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow0_col0" class="data row0 col0" >0.0264221</td>
#                         <td id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow0_col1" class="data row0 col1" >-2.19129</td>
#                         <td id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow0_col2" class="data row0 col2" >0.350807</td>
#                         <td id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow0_col3" class="data row0 col3" >0.158622</td>
#             </tr>
#             <tr>
#                                 <th id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398elevel1_row1" class="row_heading level1 row1" >2015</th>
#                         <td id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow1_col0" class="data row1 col0" >0.0120068</td>
#                         <td id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow1_col1" class="data row1 col1" >-2.80754</td>
#                         <td id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow1_col2" class="data row1 col2" >0.386903</td>
#                         <td id="T_cf5ba2b8_5bd3_11e9_978e_df8c07b9398erow1_col3" class="data row1 col3" >0.111944</td>
#             </tr>
#             <tr>
#                         <th id="T_cf5ba2b8_5bd3_
